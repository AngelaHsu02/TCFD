# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']

# %% [markdown]
# ## prepare data

# %%
train = pd.read_excel('./data/insuranceContent/ins_regression_cn_eng.xlsx')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 71 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Filename               44 non-null     object
#  1   Words_top500           44 non-null     object
#  2   Text_cleaned           44 non-null     object
#  3   Words                  44 non-null     object
#  4   Words_top100           44 non-null     object
#  5   Words_top10            44 non-null     object
#  6   vectors_Wordstop100    44 non-null     float64
#  7   vectors_Wordstop10     44 non-null     float64
#  8   vectors_Words_pca      44 non-null     float64
#  9   Year                   44 non-null     int64
#  10  Life_Ins               44 non-null     int64
#  11  Property_Ins           44 non-null     int64
#  12  Company_Name           44 non-null     object
#  13  Company_Name_CN_brief  44 non-null     object
#  14  Company_Name_CN        44 non-null     object
#  15  Score_external         44 non-null     float64
#  16  tcfd                   44 non-null     int64
#  17  esg                    44 non-null     int64
#  18  Text_uncleaned         44 non-null     object
#  19  Total_Count_Unigram    44 non-null     int64
#  20  Different_Unigrams     44 non-null     int64
#  21  TTR_Unigram500         44 non-null     int64
#  22  TTR_Unigram1000        44 non-null     int64
#  23  TTR_Unigram2000        44 non-null     int64
#  24  TTR_Unigram3000        44 non-null     int64
#  25  TTR_Unigram4000        44 non-null     int64
#  26  TTR_Unigram5000        44 non-null     int64
#  27  Entropy_Unigram500     44 non-null     float64
#  28  Entropy_Unigram1000    44 non-null     float64
#  29  Entropy_Unigram2000    44 non-null     float64
#  30  Entropy_Unigram3000    44 non-null     float64
#  31  Entropy_Unigram4000    44 non-null     float64
#  32  Entropy_Unigram5000    44 non-null     float64
#  33  Simpson_Unigram500     44 non-null     float64
#  34  Simpson_Unigram1000    44 non-null     float64
#  35  Simpson_Unigram2000    44 non-null     float64
#  36  Simpson_Unigram3000    44 non-null     float64
#  37  Simpson_Unigram4000    44 non-null     float64
#  38  Simpson_Unigram5000    44 non-null     float64
#  39  Total_Count_Bigram     44 non-null     int64
#  40  Different_Bigrams      44 non-null     int64
#  41  TTR_Bigram500          44 non-null     int64
#  42  TTR_Bigram1000         44 non-null     int64
#  43  TTR_Bigram2000         44 non-null     int64
#  44  TTR_Bigram3000         44 non-null     int64
#  45  TTR_Bigram4000         44 non-null     int64
#  46  TTR_Bigram5000         44 non-null     int64
#  47  Entropy_Bigram500      44 non-null     float64
#  48  Entropy_Bigram1000     44 non-null     float64
#  49  Entropy_Bigram2000     44 non-null     float64
#  50  Entropy_Bigram3000     44 non-null     float64
#  51  Entropy_Bigram4000     44 non-null     float64
#  52  Entropy_Bigram5000     44 non-null     float64
#  53  Simpson_Bigram500      44 non-null     float64
#  54  Simpson_Bigram1000     44 non-null     float64
#  55  Simpson_Bigram2000     44 non-null     float64
#  56  Simpson_Bigram3000     44 non-null     float64
#  57  Simpson_Bigram4000     44 non-null     float64
#  58  Simpson_Bigram5000     44 non-null     float64
#  59  資本額                    44 non-null     int64
#  60  有金控母公司                 44 non-null     int64
#  61  金控母公司名稱                44 non-null     object
#  62  金控母公司是公股               44 non-null     int64
#  63  TCFD_會計師確信             44 non-null     int64
#  64  TCFD_BSI查核             44 non-null     int64
#  65  溫室氣體驗證                 44 non-null     int64
#  66  有任第三方驗證                44 non-null     int64
#  67  Score_internal         44 non-null     float64
#  68  Rank                   44 non-null     int64
#  69  vectors_Words          44 non-null     float64
#  70  vectors_Wordstop500    44 non-null     float64
# dtypes: float64(31), int64(29), object(11)
# memory usage: 24.5+ KB

# %%
#train['vectors_Wordstop10'] = pd.to_numeric(train['vectors_Wordstop10'], errors='coerce')
#train['vectors_Wordstop100'] = pd.to_numeric(train['vectors_Wordstop100'], errors='coerce')
#train.info()
#train.to_excel('./data/insuranceContent/ins_regression_cn_eng.xlsx', index=False)

# %%
train.describe()
# Out:
#        vectors_Wordstop100  vectors_Wordstop10  vectors_Words_pca    Year  \
# count            44.000000           44.000000       4.400000e+01    44.0
# mean              1.763071           -1.672553       5.298792e-17  2022.0
# std               0.264528            0.106967       6.832828e-01     0.0
# min               1.634216           -2.040052      -1.646220e+00  2022.0
# 25%               1.666918           -1.695175      -4.469358e-01  2022.0
# 50%               1.683480           -1.684397       2.800727e-02  2022.0
# 75%               1.704964           -1.668106       3.910647e-01  2022.0
# max               2.700280           -1.242533       1.470986e+00  2022.0
#
#         Life_Ins  Property_Ins  Score_external       tcfd        esg  \
# count  44.000000     44.000000       44.000000  44.000000  44.000000
# mean    0.477273      0.522727       77.779789   0.590909   0.409091
# std     0.505258      0.505258        5.953047   0.497350   0.497350
# min     0.000000      0.000000       64.071429   0.000000   0.000000
# 25%     0.000000      0.000000       74.415179   0.000000   0.000000
# 50%     0.000000      1.000000       77.842262   1.000000   0.000000
# 75%     1.000000      1.000000       81.748512   1.000000   1.000000
# max     1.000000      1.000000       89.291667   1.000000   1.000000
#
#        Total_Count_Unigram  ...     有金控母公司   金控母公司是公股  TCFD_會計師確信  TCFD_BSI查核  \
# count            44.000000  ...  44.000000  44.000000   44.000000   44.000000
# mean           7070.750000  ...   0.363636   0.113636    0.045455    0.090909
# std           10232.585186  ...   0.486607   0.321038    0.210707    0.290803
# min             561.000000  ...   0.000000   0.000000    0.000000    0.000000
# 25%            2657.000000  ...   0.000000   0.000000    0.000000    0.000000
# 50%            4238.500000  ...   0.000000   0.000000    0.000000    0.000000
# 75%            7797.500000  ...   1.000000   0.000000    0.000000    0.000000
# max           64461.000000  ...   1.000000   1.000000    1.000000    1.000000
#
#           溫室氣體驗證    有任第三方驗證  Score_internal       Rank  vectors_Words  \
# count  44.000000  44.000000       44.000000  44.000000      44.000000
# mean    0.113636   0.250000       35.167579  22.590909       5.149038
# std     0.321038   0.438019       13.709608  12.886478       1.283418
# min     0.000000   0.000000        0.166667   1.000000       1.146583
# 25%     0.000000   0.000000       25.644535  11.750000       5.318531
# 50%     0.000000   0.000000       38.321162  23.000000       5.530931
# 75%     0.000000   0.250000       45.494000  32.250000       5.731945
# max     1.000000   1.000000       61.875878  44.000000       6.230387
#
#        vectors_Wordstop500
# count            44.000000
# mean              2.207292
# std               0.126516
# min               2.122774
# 25%               2.160718
# 50%               2.173343
# 75%               2.187563
# max               2.700280
#
# [8 rows x 60 columns]

# %%
train_l= train[(train['Life_Ins']==1)]
train_p= train[(train['Life_Ins']==0)]
train_p
# Out:
#                     Filename  \
# 21         2022_p_hotai_tcfd
# 22   2022_p_south-china_tcfd
# 23         2022_p_fubon_tcfd
# 24  2022_p_CTBC Holding_tcfd
# 25           2022_p_BNP_tcfd
# 26           2022_p_AIG_tcfd
# 27         2022_p_tfmic_tcfd
# 28         2022_p_chubb_tcfd
# 29         2022_p_taian_tcfd
# 30         2022_p_cathay_esg
# 31      2022_p_chungkuo_tcfd
# 32           2022_p_MSIG_esg
# 33         2022_p_tokio_tcfd
# 34     2022_p_taiwanfire_esg
# 35       2022_p_shinkong_esg
# 36       2022_p_wangwang_esg
# 37          2022_p_first_esg
# 38        2022_p_central_esg
# 39        2022_p_nanshan_esg
# 40         2022_p_coface_esg
# 41        2022_p_allianz_esg
# 42          2022_p_genre_esg
# 43            2022_p_RGA_esg
#
#                                          Words_top500  \
# 21  ['治理', '氣候', '治理', '架構', '全球', '氣候變遷', '企業', '...
# 22  ['氣候', '治理', '極端', '天氣', '氣候變遷', '各國', '政府', '...
# 23  ['治理', '氣候', '治理', '架構', '公司', '永續', '經營', '推動...
# 24  ['治理', '氣候', '治理', '架構', '績效', '考核', '機制', '董事...
# 25  ['氣候', '治理', '監督', '氣候', '治理', '組織', '架構', '分公...
# 26  ['治理', '氣候變遷', '公司', '治理', '公司', '台灣', '分公司', ...
# 27  ['治理', '氣候', '相關', '風險', '機會', '監督', '永續', '發展...
# 28  ['分公司', '安達', '集團', '監督', '營運', '法人', '實體', '風...
# 29  ['氣候', '治理', '架構', '公司', '氣候變遷', '風險', '管理', '...
# 30  ['氣候', '治理', '國泰產險', '氣候變遷', '治理', '架構', '氣候',...
# 31  ['氣候變遷', '治理', '支持', '氣候', '相關', '財務', '揭露', '...
# 32  ['氣候', '治理', '產險', '董事會', '氣候', '公司', '營運', '影...
# 33  ['氣候', '相關', '風險', '財務', '揭露', '公司', '董事會', '風...
# 34  ['氣候變遷', '議題', '治理', '架構', '公司', '氣候變遷', '營運',...
# 35  ['氣候變遷', '落實', '節能', '減碳', '氣候', '治理', '組織', '...
# 36  ['氣候變遷', '世界', '經濟', '全球', '風險', '報告', '全球', '...
# 37  ['氣候變遷', '風險', '機會', '因應', '對策', '全球', '暖化', '...
# 38  ['氣候變遷', '風險', '機會', '公司', '保險業', '氣候', '相關', ...
# 39  ['氣候', '治理', '董事會', '監督', '董事會', '南山', '人壽', '...
# 40  ['integration', 'csr', 'commercial', 'policy',...
# 41  ['climate', 'reporting', 'business', 'practice...
# 42  ['environmental', 'regulatory', 'requirement',...
# 43  ['framework', 'continued', 'ambition', 'alignm...
#
#                                          Text_cleaned  \
# 21  治理氣候治理架構隨著全球氣候變遷意識上升和泰產險意識到企業正面臨著前所未有的風險與挑戰為確保...
# 22  氣候治理隨著極端天氣與氣候變遷日漸嚴峻各國政府及企業應更積極思考如何共同抑制全球升溫議題年各...
# 23  治理氣候治理架構本公司設有永續經營推動小組依部門性質將公司部門分組成立六大工作小組公司治理及...
# 24  四治理氣候治理架構績效考核與薪酬機制董事中信金控董事會績效評估辦法業已明訂績效評估之衡量項目...
# 25  氣候治理與監督氣候治理組織架構與權責本分公司氣候風險管理組織架構包括經理人總經理風險管理委員...
# 26  治理氣候變遷與公司治理本公司為之台灣分公司本公司為外國公司之台灣分公司而無設置董事會因此由高...
# 27  二治理理事會對氣候相關風險與機會監督為使合作社永續發展並考慮本社規模理事會為氣候環境風險管理...
# 28  安達產險臺灣分公司作為在安達集團監督下營運的當地法人實體設有地方風險管理委員會即委員會負責實...
# 29  氣候治理架構本公司氣候變遷風險管理辦法於年底經董事會審議通過另本報告書將於每年依法規規定時程...
# 30  氣候治理國泰產險氣候變遷治理架構對於氣候相關風險與機會之治理國泰產險以低碳永續經營為目標由董...
# 31  氣候變遷治理兆豐金控已於年月簽署支持氣候相關財務揭露倡議依循架構揭露氣候相關資訊兆豐保險為兆...
# 32  氣候治理明台產險董事會重視氣候對公司營運的影響永續委員會由總經理擔任主席永續委員會下的公司治...
# 33  氣候相關風險財務揭露資訊本公司董事會對於風險管理並非僅止於關注個別風險如氣候變遷風險之影響更...
# 34  氣候變遷議題治理架構本公司為掌握氣候變遷對自身營運金融操作與服務所帶來之風險及機會以永續發展...
# 35  響應氣候變遷落實節能減碳氣候治理組織新光產險因應氣候變遷風險對企業與地球的重要性為有效調控氣...
# 36  氣候變遷積極來守護世界經濟論壇發佈年全球風險報告指出除了仍在肆虐的新冠疫情年全球面臨的主要風...
# 37  氣候變遷之風險與機會及因應對策因全球暖化導致極端氣候的產生近幾年環保意識節能減碳及衛生安全相...
# 38  氣候變遷的風險與機會本公司參照保險業氣候相關風險財務揭露指引制定氣候相關風險財務揭露政策持續...
# 39  氣候治理董事會監督董事會是南山人壽氣候相關風險及機會議題的最高督導單位除負責核定氣候相關風險...
# 40  integration csr commercial policy commercial e...
# 41  strive continuously enhance climate changerela...
# 42  environmental gen complies applicable legal re...
# 43  framework continued pursue ambition throughout...
#
#                                                 Words  \
# 21  ['治理', '氣候', '治理', '架構', '全球', '氣候變遷', '意識', '...
# 22  ['氣候', '治理', '極端', '天氣', '氣候變遷', '日漸', '嚴峻', '...
# 23  ['治理', '氣候', '治理', '架構', '公司', '設有', '永續', '經營...
# 24  ['治理', '氣候', '治理', '架構', '績效', '考核', '薪酬', '機制...
# 25  ['氣候', '治理', '監督', '氣候', '治理', '組織', '架構', '權責...
# 26  ['治理', '氣候變遷', '公司', '治理', '公司', '台灣', '分公司', ...
# 27  ['治理', '理事', '氣候', '相關', '風險', '機會', '監督', '合作...
# 28  ['安達產險', '分公司', '安達', '集團', '監督', '營運', '法人', ...
# 29  ['氣候', '治理', '架構', '公司', '氣候變遷', '風險', '管理', '...
# 30  ['氣候', '治理', '國泰產險', '氣候變遷', '治理', '架構', '氣候',...
# 31  ['氣候變遷', '治理', '兆豐金控', '簽署', '支持', '氣候', '相關',...
# 32  ['氣候', '治理', '明台', '產險', '董事會', '重視', '氣候', '公...
# 33  ['氣候', '相關', '風險', '財務', '揭露', '資訊本', '公司', '董...
# 34  ['氣候變遷', '議題', '治理', '架構', '公司', '氣候變遷', '營運',...
# 35  ['響應', '氣候變遷', '落實', '節能', '減碳', '氣候', '治理', '...
# 36  ['氣候變遷', '積極來', '守護', '世界', '經濟', '論壇', '全球', ...
# 37  ['氣候變遷', '風險', '機會', '因應', '對策', '全球', '暖化', '...
# 38  ['氣候變遷', '風險', '機會', '公司', '參照', '保險業', '氣候', ...
# 39  ['氣候', '治理', '董事會', '監督', '董事會', '南山', '人壽', '...
# 40  ['integration', 'csr', 'commercial', 'policy',...
# 41  ['strive', 'continuously', 'enhance', 'climate...
# 42  ['environmental', 'gen', 'complies', 'applicab...
# 43  ['framework', 'continued', 'pursue', 'ambition...
#
#                                          Words_top100  \
# 21  ['治理', '氣候', '治理', '架構', '全球', '氣候變遷', '企業', '...
# 22  ['氣候', '治理', '氣候變遷', '企業', '全球', '議題', '氣候', '...
# 23  ['治理', '氣候', '治理', '架構', '公司', '永續', '推動', '公司...
# 24  ['治理', '氣候', '治理', '架構', '機制', '中信', '金控', '董事...
# 25  ['氣候', '治理', '氣候', '治理', '架構', '分公司', '氣候', '風...
# 26  ['治理', '氣候變遷', '公司', '治理', '公司', '分公司', '公司', ...
# 27  ['治理', '氣候', '相關', '風險', '機會', '永續', '發展', '氣候...
# 28  ['分公司', '集團', '營運', '實體', '風險', '管理', '委員會', '...
# 29  ['氣候', '治理', '架構', '公司', '氣候變遷', '風險', '管理', '...
# 30  ['氣候', '治理', '氣候變遷', '治理', '架構', '氣候', '相關', '...
# 31  ['氣候變遷', '治理', '氣候', '相關', '財務', '揭露', '架構', '...
# 32  ['氣候', '治理', '董事會', '氣候', '公司', '營運', '影響', '永...
# 33  ['氣候', '相關', '風險', '財務', '揭露', '公司', '董事會', '風...
# 34  ['氣候變遷', '議題', '治理', '架構', '公司', '氣候變遷', '營運',...
# 35  ['氣候變遷', '減碳', '氣候', '治理', '因應', '氣候變遷', '風險',...
# 36  ['氣候變遷', '全球', '風險', '報告', '全球', '風險', '氣候變遷',...
# 37  ['氣候變遷', '風險', '機會', '因應', '全球', '氣候', '減碳', '...
# 38  ['氣候變遷', '風險', '機會', '公司', '氣候', '相關', '風險', '...
# 39  ['氣候', '治理', '董事會', '董事會', '人壽', '氣候', '相關', '...
# 40  ['csr', 'policy', 'policy', 'country', 'coface...
# 41  ['climate', 'reporting', 'business', 'practice...
# 42  ['environmental', 'environmental', 'initiative...
# 43  ['commitment', 'climate', 'risk', 'business', ...
#
#                                           Words_top10  vectors_Wordstop100  \
# 21  ['氣候', '氣候變遷', '風險', '氣候', '風險', '管理', '氣候變遷',...             1.663165
# 22  ['氣候', '氣候變遷', '氣候', '氣候', '氣候變遷', '影響', '氣候',...             1.667855
# 23  ['氣候', '公司', '公司', '公司', '氣候變遷', '風險', '相關', '...             1.722028
# 24  ['氣候', '評估', '公司', '氣候', '評估', '評估', '氣候', '相關...             1.719259
# 25  ['氣候', '氣候', '氣候', '風險', '管理', '風險', '管理', '風險...             1.658511
# 26  ['氣候變遷', '公司', '公司', '公司', '公司', '管理', '風險', '...             1.662367
# 27  ['氣候', '相關', '風險', '氣候', '風險', '管理', '管理', '氣候...             1.681959
# 28  ['風險', '管理', '氣候', '風險', '管理', '風險', '管理', '風險...             1.695063
# 29  ['氣候', '公司', '氣候變遷', '風險', '管理', '公司', '氣候', '...             1.713531
# 30  ['氣候', '氣候變遷', '氣候', '相關', '風險', '管理', '氣候', '...             1.686766
# 31  ['氣候變遷', '氣候', '相關', '氣候', '相關', '氣候', '相關', '...             1.689359
# 32  ['氣候', '氣候', '公司', '影響', '公司', '氣候', '相關', '氣候...             1.674126
# 33  ['氣候', '相關', '風險', '公司', '風險', '管理', '風險', '氣候...             1.671727
# 34  ['氣候變遷', '公司', '氣候變遷', '風險', '公司', '風險', '管理',...             1.667806
# 35  ['氣候變遷', '氣候', '氣候變遷', '風險', '氣候', '風險', '公司',...             1.699509
# 36  ['氣候變遷', '風險', '風險', '氣候變遷', '風險', '風險', '氣候',...             1.653333
# 37  ['氣候變遷', '風險', '氣候', '相關', '評估', '公司', '風險', '...             1.705457
# 38  ['氣候變遷', '風險', '公司', '氣候', '相關', '風險', '氣候', '...             1.687852
# 39  ['氣候', '氣候', '相關', '風險', '氣候', '相關', '風險', '管理...             1.667081
# 40  ['coface', 'business', 'risk', 'coface', 'busi...             2.700280
# 41                           ['business', 'business']             2.357439
# 42  ['environmental', 'environmental', 'environmen...             2.593852
# 43  ['risk', 'business', 'carbon', 'scope', 'emiss...             2.658234
#
#     vectors_Wordstop10  vectors_Words_pca  Year  ...  金控母公司名稱  金控母公司是公股  \
# 21           -1.667082          -1.271603  2022  ...        無         0
# 22           -1.671871          -0.113321  2022  ...      華南金         1
# 23           -1.694294           0.621497  2022  ...      富邦金         0
# 24           -1.718119           1.470986  2022  ...      中信金         0
# 25           -1.665366          -0.621548  2022  ...        無         0
# 26           -1.676413          -0.414798  2022  ...        無         0
# 27           -1.685329           0.380739  2022  ...        無         0
# 28           -1.660102           0.351846  2022  ...        無         0
# 29           -1.690848           0.477879  2022  ...        無         0
# 30           -1.677268          -0.047503  2022  ...      國泰金         0
# 31           -1.673044          -0.585965  2022  ...      兆豐金         1
# 32           -1.674136          -0.528337  2022  ...        無         0
# 33           -1.692100           0.369337  2022  ...        無         0
# 34           -1.701267          -0.410636  2022  ...        無         0
# 35           -1.679270           0.422042  2022  ...      新光金         0
# 36           -1.675545          -0.734923  2022  ...        無         0
# 37           -1.691738          -0.404056  2022  ...        無         0
# 38           -1.695003           0.163193  2022  ...        無         0
# 39           -1.695175          -0.003391  2022  ...        無         0
# 40           -1.638764          -0.068512  2022  ...        無         0
# 41           -2.040052           0.059406  2022  ...        無         0
# 42           -1.279696           0.084647  2022  ...        無         0
# 43           -1.242533          -0.075541  2022  ...        無         0
#
#    TCFD_會計師確信 TCFD_BSI查核 溫室氣體驗證  有任第三方驗證  Score_internal  Rank vectors_Words  \
# 21          0          0      0        0       25.959700    33      5.815554
# 22          0          0      0        0       57.461256     3      5.615370
# 23          0          0      0        0       40.067344    21      5.276626
# 24          1          0      0        1       39.164784    19      5.487936
# 25          0          0      0        0       26.280731    32      5.643857
# 26          0          0      0        0       28.412388    29      5.463338
# 27          0          0      0        0       12.916417    42      4.687719
# 28          0          0      0        0       14.093361    40      5.188644
# 29          0          0      0        0       45.466892    12      5.439302
# 30          0          0      0        0       55.992481     1      5.529265
# 31          0          0      0        0       46.140352     7      5.869369
# 32          0          0      0        0       24.699043    34      5.687697
# 33          0          0      0        0       27.199157    30      5.366354
# 34          0          0      0        0       21.823645    38      6.230387
# 35          0          1      0        1       22.720090    13      5.042768
# 36          0          0      0        0       45.983876     8      5.532597
# 37          0          0      0        0       22.467418    37      5.456229
# 38          0          0      1        1       39.114934    20      5.742122
# 39          0          0      1        1       28.941404    28      5.731945
# 40          0          0      0        0       10.176963    43      1.218850
# 41          0          0      0        0       26.977095    31      1.146583
# 42          0          0      0        0        0.166667    44      1.257047
# 43          0          0      0        0       20.188950    39      1.310254
#
#     vectors_Wordstop500
# 21             2.178701
# 22             2.155071
# 23             2.172286
# 24             2.171859
# 25             2.166092
# 26             2.185301
# 27             2.175232
# 28             2.187475
# 29             2.187604
# 30             2.122774
# 31             2.165068
# 32             2.187706
# 33             2.158528
# 34             2.131597
# 35             2.164891
# 36             2.146532
# 37             2.183401
# 38             2.165230
# 39             2.150606
# 40             2.700280
# 41             2.357439
# 42             2.593852
# 43             2.658234
#
# [23 rows x 71 columns]

# %%
#import matplotlib.pyplot as plt

## 數值型變數的基本描述
#numeric_cols = train_p.select_dtypes(include=['float64', 'int64'])

#numeric_cols.hist(figsize=(20, 15), bins=30, edgecolor='black')
#plt.tight_layout()
#plt.show()

# %% [markdown]
# ## Do not execute! Save 500 times train-val indices

# %%
# 重新設定 train_p 的索引
train_p = train_p.reset_index(drop=True)

# %%
X = train_p.drop(columns=['Score_internal', 'Score_external','Rank',
                        'Filename', 'Year', 'Company_Name', 'Life_Ins', 'Property_Ins', 'Company_Name_CN_brief', 'Company_Name_CN', '金控母公司名稱',
                        'Text_cleaned','Text_uncleaned', 'Words', 'Words_top10', 'Words_top100', 'Words_top500' 
])   

y= train_p['Score_external']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   vectors_Wordstop100  23 non-null     float64
#  1   vectors_Wordstop10   23 non-null     float64
#  2   vectors_Words_pca    23 non-null     float64
#  3   tcfd                 23 non-null     int64
#  4   esg                  23 non-null     int64
#  5   Total_Count_Unigram  23 non-null     int64
#  6   Different_Unigrams   23 non-null     int64
#  7   TTR_Unigram500       23 non-null     int64
#  8   TTR_Unigram1000      23 non-null     int64
#  9   TTR_Unigram2000      23 non-null     int64
#  10  TTR_Unigram3000      23 non-null     int64
#  11  TTR_Unigram4000      23 non-null     int64
#  12  TTR_Unigram5000      23 non-null     int64
#  13  Entropy_Unigram500   23 non-null     float64
#  14  Entropy_Unigram1000  23 non-null     float64
#  15  Entropy_Unigram2000  23 non-null     float64
#  16  Entropy_Unigram3000  23 non-null     float64
#  17  Entropy_Unigram4000  23 non-null     float64
#  18  Entropy_Unigram5000  23 non-null     float64
#  19  Simpson_Unigram500   23 non-null     float64
#  20  Simpson_Unigram1000  23 non-null     float64
#  21  Simpson_Unigram2000  23 non-null     float64
#  22  Simpson_Unigram3000  23 non-null     float64
#  23  Simpson_Unigram4000  23 non-null     float64
#  24  Simpson_Unigram5000  23 non-null     float64
#  25  Total_Count_Bigram   23 non-null     int64
#  26  Different_Bigrams    23 non-null     int64
#  27  TTR_Bigram500        23 non-null     int64
#  28  TTR_Bigram1000       23 non-null     int64
#  29  TTR_Bigram2000       23 non-null     int64
#  30  TTR_Bigram3000       23 non-null     int64
#  31  TTR_Bigram4000       23 non-null     int64
#  32  TTR_Bigram5000       23 non-null     int64
#  33  Entropy_Bigram500    23 non-null     float64
#  34  Entropy_Bigram1000   23 non-null     float64
#  35  Entropy_Bigram2000   23 non-null     float64
#  36  Entropy_Bigram3000   23 non-null     float64
#  37  Entropy_Bigram4000   23 non-null     float64
#  38  Entropy_Bigram5000   23 non-null     float64
#  39  Simpson_Bigram500    23 non-null     float64
#  40  Simpson_Bigram1000   23 non-null     float64
#  41  Simpson_Bigram2000   23 non-null     float64
#  42  Simpson_Bigram3000   23 non-null     float64
#  43  Simpson_Bigram4000   23 non-null     float64
#  44  Simpson_Bigram5000   23 non-null     float64
#  45  資本額                  23 non-null     int64
#  46  有金控母公司               23 non-null     int64
#  47  金控母公司是公股             23 non-null     int64
#  48  TCFD_會計師確信           23 non-null     int64
#  49  TCFD_BSI查核           23 non-null     int64
#  50  溫室氣體驗證               23 non-null     int64
#  51  有任第三方驗證              23 non-null     int64
#  52  vectors_Words        23 non-null     float64
#  53  vectors_Wordstop500  23 non-null     float64
# dtypes: float64(29), int64(25)
# memory usage: 9.8 KB

# %%
train_val_indices = {
    'train_indices': [],
    'val_indices': []
}

numTrials = 500
train_sample = 0
val_sample = 0
traindistribution = 0
valdistribution = 0

for i in range(numTrials):
    # 保存訓練和驗證集的索引
    # 使用train_test_split來切分資料，但只記錄索引，去掉stratify參數
    X_train_indices, X_val_indices, _, _ = train_test_split(np.arange(len(X)), y, test_size=0.2, random_state=None)
    print(f'Train indices_{i}:{X_train_indices},Val indices_{i}:{X_val_indices}')
    train_val_indices['train_indices'].append(X_train_indices.tolist())
    train_val_indices['val_indices'].append(X_val_indices.tolist())
    # Get train/val set y distribution stats 
    traindistribution += pd.Series(y[X_train_indices]).describe()
    valdistribution += pd.Series(y[X_val_indices]).describe()
    train_sample += len(X_train_indices)
    val_sample += len(X_val_indices)
## 保存切分索引
np.save('train_val_indices_regression_property_simulation500.npy', train_val_indices, allow_pickle=True)

print(f"Train sample:{train_sample}\nVal sample:{val_sample}")
print(f"Train distribution:\n{traindistribution/numTrials}\nVal distribution:\n{valdistribution/numTrials}")
# Out:
# Train indices_0:[22 10  0 20 12  6 18  5 11 19  2  1 15  7 14  8 16 21],Val indices_0:[ 9 13  3 17  4]
# Train indices_1:[11 10  1 14 18 21  3  7 17 16 20 12  8 22 13  9  0 15],Val indices_1:[ 6 19  2  4  5]
# Train indices_2:[11  9  1  4  3  2 20 22  8  0 10 15 12 16  7 14  5  6],Val indices_2:[17 13 21 18 19]
# Train indices_3:[16 11  0  5 20  9 15 22 19 17  7  8 21  1 12 14 10  3],Val indices_3:[ 2  6 13  4 18]
# Train indices_4:[17  3 10 13 21 11  1  5  0 12 22 14 18 20 15  7 16  8],Val indices_4:[ 4  6 19  9  2]
# Train indices_5:[ 0 21 17 19  2 14 13 15  4  7  1  5  8 20 11 18 10 16],Val indices_5:[22  9  6  3 12]
# Train indices_6:[ 8 16 17 10  0  3  5 15 19  7 12 13 20 18 22  4  6 11],Val indices_6:[ 9 21  2  1 14]
# Train indices_7:[ 1 16 13 22 21 10  2 20  0 14  6  4 17  8  5  7  9 15],Val indices_7:[18 19 12  3 11]
# Train indices_8:[ 1 19  6  0 22 18  8  5  7 17 21 15 20 11  2 10 16 12],Val indices_8:[ 3 13  4 14  9]
# Train indices_9:[ 4 22 18 17  6  9 15  7 10 11  1  3  5 19 21 20  8 13],Val indices_9:[ 2  0 16 12 14]
# Train indices_10:[ 7 19  5 22 15 10  0 12 20  3  9  6 21 13  2  4 14  1],Val indices_10:[ 8 17 18 11 16]
# Train indices_11:[10  8 15  1 20  4 13 22 16  6  9 17 18  3 14  2 12  0],Val indices_11:[ 7 11 19 21  5]
# Train indices_12:[10 15 20  8  6  3  0 12  9 22  2 21 16 13 17  1  5 19],Val indices_12:[18  4 14 11  7]
# Train indices_13:[ 6  2  1  9  8  0 16 12  7  4 15 22  3 19  5 21 18 13],Val indices_13:[20 14 10 17 11]
# Train indices_14:[ 3  6 21 16 19 17 20 13  8  1 11  9  4 18  7  0 22  5],Val indices_14:[ 2 10 15 14 12]
# Train indices_15:[ 9  7 19 22 21 18 10  1 11  5  4 14 13 16 12  6  8 20],Val indices_15:[ 0 15  2  3 17]
# Train indices_16:[12 14  1  3 18  7 17  6  0 16  2 20 10  5 11 19 22  9],Val indices_16:[13  8  4 21 15]
# Train indices_17:[14 13 15 11  9  2 16 21  0 12  8  5  1  3 10  7 18  6],Val indices_17:[22 19 20 17  4]
# Train indices_18:[ 3 21 19 16  5 18  9 13  2  7  0  4 22 17 10  8 20 14],Val indices_18:[ 6  1 15 11 12]
# Train indices_19:[ 4  9  0  8 21 11 18 10 14  2 22  7 20 12  6 19 13 16],Val indices_19:[ 3 17  1 15  5]
# Train indices_20:[17 19  0  6  4 21 15  1  9 10  5 22 12  3 18 11 16 20],Val indices_20:[ 2  8  7 14 13]
# Train indices_21:[19 11 22  7 16 12  6  8 10 18  9 17  0 14 20  4 15  3],Val indices_21:[ 1  2  5 13 21]
# Train indices_22:[17 18  3 22  2 16  7  4 13  8  6  5 20  9 21  1 19 15],Val indices_22:[11 12  0 14 10]
# Train indices_23:[20 21 16 17  4 13 19 22 15  1 10  9  8 12 18  7  2  3],Val indices_23:[ 6 11  0  5 14]
# Train indices_24:[19  8 22 21 16 12  7  9  1 20 15 14 11  0 17 18  5  2],Val indices_24:[ 3  6 10  4 13]
# Train indices_25:[10 16  1 17  4  6 15  2 21 14 20 18  0  9  3 19  7 13],Val indices_25:[11  8 12 22  5]
# Train indices_26:[20  2  0 21 18 12 22 14 10 17 15  5 16 11  3  6  8  7],Val indices_26:[ 4  1 19 13  9]
# Train indices_27:[ 6  1 19 21  2  8 11 12 20 15  4  7  9  0  3 17 16 14],Val indices_27:[10  5 18 22 13]
# Train indices_28:[ 2 17 14 19  0  1  7 20 21 16  3 11  9 12 10  4 13  6],Val indices_28:[22  8 18 15  5]
# Train indices_29:[12  4 21 16 13 20 15  1  0 10  8 11 22  7 17 14  5  6],Val indices_29:[ 2  3 19 18  9]
# Train indices_30:[15  4 19  7  8 13  1 11 16  5 22  0 18  3 10 14 21 20],Val indices_30:[12 17  9  2  6]
# Train indices_31:[ 9 20  6 19 18  0 22  7 17 13 10 11  1 15  8 21  2  5],Val indices_31:[ 3 12 16 14  4]
# Train indices_32:[18  4 12 11  5 19  3 22  2  1 10 13  6 17  0 21  9  8],Val indices_32:[16  7 14 20 15]
# Train indices_33:[12 16  7 22  3  5 15 18 17  8 19 21  9  4 13 11  0  6],Val indices_33:[ 1  2 14 10 20]
# Train indices_34:[14  7 22 11 15  3  2  4 21  1  0 19  5 12  6 20  8  9],Val indices_34:[10 18 17 13 16]
# Train indices_35:[14  8  7 21 15 17 22  2  6 16  0  1  3 11  5 10  9 12],Val indices_35:[ 4 13 20 18 19]
# Train indices_36:[17  9  2 10  6 15 19  3  4 16  0 12  7 18 22  8 13 14],Val indices_36:[ 1 21  5 11 20]
# Train indices_37:[ 6  1 22 15 14 19  4 17 20 16  9  5  3  7  2 13 10 18],Val indices_37:[ 8 11  0 12 21]
# Train indices_38:[ 7  9 11 21 20  6  0 18  2 15  3  8 14 12 22  5  4 10],Val indices_38:[13  1 19 16 17]
# Train indices_39:[ 2  3 17 13 10  1  5  0 15 21 20 11 18  7  8  4  6 14],Val indices_39:[22 16 12 19  9]
# Train indices_40:[17 21 13  1  6 16 11 22  3 15  2 12  5  0 19 10  9  4],Val indices_40:[20  7 18 14  8]
# Train indices_41:[22 11 21  3 13 14  5 12  7  4 17  6  2 20 10  1 19 15],Val indices_41:[16  8  0 18  9]
# Train indices_42:[ 0 18  3  7 22 21  8  5 19 13 16 20  6 17 12  4  2 14],Val indices_42:[10 15  9  1 11]
# Train indices_43:[10  3  6 18  5 11 20 13 14 22 17 15 21 16  1  8 19  4],Val indices_43:[12  7  2  9  0]
# Train indices_44:[20 18  9 21 19 13 16  1 10 12  4  2  8  7 15  3  0 17],Val indices_44:[11  5  6 14 22]
# Train indices_45:[22  0 14 19  4  5 21  8  3 18 17  9  6 13 16 12 15 11],Val indices_45:[20  2  1  7 10]
# Train indices_46:[ 1  2  5  0 15  4  9 21 11 18 20 10 17  6 14 16 22  7],Val indices_46:[ 3 19  8 13 12]
# Train indices_47:[20 21  8 19 13  1  4  2  6 10 18 14 17  3  9  7 15  0],Val indices_47:[12  5 16 11 22]
# Train indices_48:[ 8 15 18 16 17 11  4  1  9 10  2  5 20  6 13  7 21  3],Val indices_48:[ 0 14 22 12 19]
# Train indices_49:[21  3 12  2  0  7 14  1 10 11 13  4  6 19  5 20 18 22],Val indices_49:[16 17  9 15  8]
# Train indices_50:[ 3  6 11  5  2 19 22 12  8  1  9 21 15 10 16 17  0 14],Val indices_50:[ 7 13 20 18  4]
# Train indices_51:[ 8  5 20  1 21 13 11 14 19 16  0 15 10  2 12  4  9  7],Val indices_51:[17  6  3 22 18]
# Train indices_52:[ 8  9 22 14 20 17  3  4  1 13 15 11 16 21 10  5  7 19],Val indices_52:[ 2  6 18 12  0]
# Train indices_53:[13  7  9  5 18  6 10 15  8  4  0  2 21  3 20 17 11 16],Val indices_53:[14 12 22 19  1]
# Train indices_54:[15  5 19 18  4  2 12 13 14 16  1  6 22 17 21 10 11  0],Val indices_54:[ 9 20  7  8  3]
# Train indices_55:[16 10 11 21 20  3 18  4  5  1 15  9  7  6 22 13 17 14],Val indices_55:[12 19  2  8  0]
# Train indices_56:[14 16 17  7 21 15 22 12  9  4  1 20  8  2  6  3  0 13],Val indices_56:[19 18  5 11 10]
# Train indices_57:[21 18 10  5  7 20  4 13  6 22 16 17  2 15 14 12 11  0],Val indices_57:[19  8  3  1  9]
# Train indices_58:[ 9 21 11  8  4  5  6 18 13  3 19 14 16  0 20  2 12 10],Val indices_58:[22 17  1 15  7]
# Train indices_59:[ 0  3 21  9 20 13 14  8 19  6  2 15 10  7 11 18 22 12],Val indices_59:[ 1  5  4 17 16]
# Train indices_60:[ 8  7  6 10 14  3 13 12 15  1  9 16  2 18 17 11 22 21],Val indices_60:[ 5 19  0  4 20]
# Train indices_61:[ 6 22 12  9  3  5 17 16  1 14  7  2 15 20 11 10  4  8],Val indices_61:[ 0 19 13 21 18]
# Train indices_62:[22 10 19 15  7  6 21  2  3  5 16 20  9  4 12 17  0 14],Val indices_62:[13  1  8 11 18]
# Train indices_63:[19  2 16 13 21  3 10  7 14 18 20 15  0  8  6 11  9  1],Val indices_63:[ 4 12 22 17  5]
# Train indices_64:[16 11  6  2 19 22  1 12 10 18  5 15  4 17  8 20 21  9],Val indices_64:[13  3 14  0  7]
# Train indices_65:[ 3 12  6 10  0 13 14 18 21  7 19 16  9  8 11  1  4 20],Val indices_65:[15 22  2  5 17]
# Train indices_66:[18 14  2 16  3  8 20  0  1 12  9 17 19  5  6  7  4 21],Val indices_66:[15 10 11 22 13]
# Train indices_67:[ 3 10 16 22  9  0 21  1 11  5  7 13 14 15 18  4  8 19],Val indices_67:[17  2 20 12  6]
# Train indices_68:[20 11 15  5  3 13 12  0  9  4 16  1  8 22 17 14  6 21],Val indices_68:[10 19  2 18  7]
# Train indices_69:[14  1 15 16 12  9  2 19 17 18  0 22  5  6 20  8 21  7],Val indices_69:[10  3 13 11  4]
# Train indices_70:[22 12  4  2 15  8 19 21 16 10 13  5 14  7  3 20 11 18],Val indices_70:[ 1  9  0  6 17]
# Train indices_71:[18  8  0  9 10 11 20 14  6  7 22 13  4  5 16 12  1 15],Val indices_71:[21  2 19 17  3]
# Train indices_72:[22  8  6 12 17  0  3 20  2 11 16  1 15 19 14  9  5 13],Val indices_72:[ 7  4 10 21 18]
# Train indices_73:[15  0  2  1 19  4 14 16 13 12 18  7 11 21  5 17 20  9],Val indices_73:[ 3 22  8 10  6]
# Train indices_74:[21 20 14 16 17  2  7 15  0 22  6  1 13 10  4 18 12  5],Val indices_74:[ 3 19 11  8  9]
# Train indices_75:[20 17 14  2  6 13 10  3  4 11 16 12 22  9  1  8 18  7],Val indices_75:[19 15 21  5  0]
# Train indices_76:[10 15 19 18  1  9 14  8  4  6 20 13  3 21 16 17  0  2],Val indices_76:[ 5  7 22 12 11]
# Train indices_77:[ 1  4  2  3 14 10 16 20 15 11  5 21 13 17  7  9 22  0],Val indices_77:[12  8  6 18 19]
# Train indices_78:[ 2 18 21 16 12  3 11  0  5 19  4  7 14  9 15 17 22 20],Val indices_78:[ 6  1 13  8 10]
# Train indices_79:[ 6  4  2  9  3  5 11 21  8 14 16 13 10 20 19 17 15 12],Val indices_79:[22  0  1 18  7]
# Train indices_80:[ 5 11 20  1 12  0  4  7 19 10  9 18 15  8 21 17 14 16],Val indices_80:[ 6  2 13 22  3]
# Train indices_81:[ 3  7  1  8 14 18 15  4 10 22 16  2  6 12 17 13  5  9],Val indices_81:[ 0 19 20 21 11]
# Train indices_82:[ 9  5  1 16  4 15 20 12  6 17 22 13 10 18  3  0 14  7],Val indices_82:[19  2  8 21 11]
# Train indices_83:[ 3 15 21 11 16 12  6  4 22 20  9  2  8  5 14 19  7 18],Val indices_83:[ 0 17 10 13  1]
# Train indices_84:[14  1  3 22 12 11 18 16 13 21  0 19 17  8  7 20  9 10],Val indices_84:[ 2  6 15  5  4]
# Train indices_85:[14  5 10 11 18 22 15 13  4 19  8  9  7 16  1 21 12  6],Val indices_85:[17 20  3  2  0]
# Train indices_86:[16  5 11  1  8 13  2 18  9 10 12 17 22 20  7  6 14  4],Val indices_86:[ 0 15 19 21  3]
# Train indices_87:[15  2 12  6  3  0  9 17 18 16  7  4 19 20  8  1 22 13],Val indices_87:[10 11  5 14 21]
# Train indices_88:[14 11  9 20 19 15  0  2 13 18 17  7  4  1  3 12 21 22],Val indices_88:[ 6  5 16  8 10]
# Train indices_89:[ 7 15 12 17  9  1  2  8 11 16  4 21 13  6 10  5 14  0],Val indices_89:[22 18  3 20 19]
# Train indices_90:[ 0  9  1 20 12  7  8  5 14 13 15 19  3 10  6 16 11 21],Val indices_90:[18 17  2  4 22]
# Train indices_91:[ 3 16 19 14 15 17 20 22 18  1 21 10  8  9 11  7  5  4],Val indices_91:[ 2 12  0 13  6]
# Train indices_92:[ 9  4  2 21 18 19 13  7  5  6 10  0  3 11 12  1 20 14],Val indices_92:[17  8 16 22 15]
# Train indices_93:[ 2  1 22  4 13 12 17 18 21 11  7  9 15  5  8  6 14 16],Val indices_93:[ 3 10 19  0 20]
# Train indices_94:[ 0  5 14  3  9 13  4 18  6  7 12  2 21 22 10 17  8 19],Val indices_94:[15 20 11 16  1]
# Train indices_95:[ 4 19 12 20 18  1 13 14  9 22  3  7  6 10  2  5 17 16],Val indices_95:[15 11  0 21  8]
# Train indices_96:[11 13  2  8 19  6  0  9  1  3 10 12 16 18  7 15 20 14],Val indices_96:[ 4 21  5 22 17]
# Train indices_97:[10 15  4  6  2  7 14 17  8 22  0 13 21 11  9  1 20 18],Val indices_97:[ 5 19 16 12  3]
# Train indices_98:[ 7 11 22  2 18 19 13 16 14  6  3  5 17  0 15 20 21 10],Val indices_98:[12  4  9  1  8]
# Train indices_99:[ 1 22  8  9  3 17 20 11 19  6 14 21 18  2  5 13  4 12],Val indices_99:[15  7 16  0 10]
# Train indices_100:[ 7 21  3 19 10 12 15 18 20  6 17  0  8  4 22 16 11  5],Val indices_100:[ 1 13 14  2  9]
# Train indices_101:[ 8 15  6  4  2 18  7 17 11 19 10 12 21  3 16 13 20 22],Val indices_101:[ 9  5  0 14  1]
# Train indices_102:[ 2 14  9 13  6 19 17 18  1  5  3 16 12 15  8  4 21 20],Val indices_102:[ 0 22 10 11  7]
# Train indices_103:[ 0  3 10 13  9 11  8  7  5 17  2 22 14 16  1  4 15 19],Val indices_103:[18 21  6 20 12]
# Train indices_104:[ 9 16 14 18  0  7 22  2 11  3 19 10 15 12 21  1 17  6],Val indices_104:[ 4 13  5 20  8]
# Train indices_105:[ 3 13 21  6 10  8 15  7  5 12  4 17 20 11  9 22 19  2],Val indices_105:[ 1  0 18 14 16]
# Train indices_106:[13  2 17  7  4 11 16  9  8 19  0 10  1  5 12  3  6 18],Val indices_106:[22 21 20 15 14]
# Train indices_107:[ 4 20 17  8 19 12  2  5  3 11  6 21  0 16 15 10  9 18],Val indices_107:[ 1 13 14 22  7]
# Train indices_108:[10 14 21 11 17  3  1  7  9 22 18 16 13  8  4  2 20 12],Val indices_108:[ 5 15 19  6  0]
# Train indices_109:[ 2  4 17  8 12  3  0 15  6 22 13 11 18  1 20 19  5  9],Val indices_109:[16 21 10  7 14]
# Train indices_110:[13  2 17  9 20 10 11 22 19 16  0 12 15 21  6  1  7  4],Val indices_110:[ 8  5  3 14 18]
# Train indices_111:[16 12 20  6  1  4  5 22  8  0  2  7 13 15  9 10 14 17],Val indices_111:[ 3 21 11 19 18]
# Train indices_112:[20 11 18 12  4 17  5  6 16  0 10 19 15 21  8 22  1  3],Val indices_112:[13 14  2  9  7]
# Train indices_113:[22 18 11  7  4  3  5 15 12  1 13  0 20 19 14  9  2 16],Val indices_113:[21 17  8 10  6]
# Train indices_114:[ 9  2  5 13 18  7  4 19 11  1 20  3 16  0 10 14 12  6],Val indices_114:[21 22  8 17 15]
# Train indices_115:[ 0  6 11 15 18  5  7  9 10  4 20  1 12 14 22 21 16  8],Val indices_115:[17  2 19  3 13]
# Train indices_116:[11 19  2 22  5  7 18  8 14  3 13  9  6 20  1 16  4 17],Val indices_116:[15 21 12  0 10]
# Train indices_117:[ 2  7  6 18  3 21 22  8  1 15  0  9 17 13 12  5 16  4],Val indices_117:[10 20 11 14 19]
# Train indices_118:[20 21 13  2 15  0 19  8  4 10  3  6 22 14 17 18  1 12],Val indices_118:[ 9  5 16 11  7]
# Train indices_119:[17  6 14 12  2 18  5  4 20 10 11 19  8  9  1 15 21 16],Val indices_119:[ 0 13  7 22  3]
# Train indices_120:[10 16 11 17 15  6  4 12 21  0 18 20  5  7 13 14  1 19],Val indices_120:[ 3 22  2  9  8]
# Train indices_121:[10  7 20 22  1 15 13  6  9  5  0 16 19  3 21 12 18 14],Val indices_121:[ 4  8 17  2 11]
# Train indices_122:[ 5 21 10 14 15 19 17  2 13 20  4  9 16  6  7 12  0  3],Val indices_122:[18  1  8 22 11]
# Train indices_123:[ 7  3  8 20  5  1 11 17 16 21 13 12 22 15 18 19  2 10],Val indices_123:[ 4 14  6  9  0]
# Train indices_124:[ 9  4  2 12  7 21 20 19 10  3 13 15 16 22  0  1 11  5],Val indices_124:[17 18  8 14  6]
# Train indices_125:[15  3  5  1 16 11  4 18  8 12 17  6 10  2  7 21  0 22],Val indices_125:[13 20  9 14 19]
# Train indices_126:[ 9  2 11  6 19 14 17  0  4 12  1  8  5  3 20 22 10 16],Val indices_126:[18 15 21 13  7]
# Train indices_127:[22  4 13 14  6 17 19  9  5  1 15 11  8 20  0 21  2  3],Val indices_127:[12 16  7 10 18]
# Train indices_128:[ 4 15  7  2  3 22 19  9 21 20 13  1 12  5 14 17  8 16],Val indices_128:[ 6 11  0 10 18]
# Train indices_129:[ 1  8  3  9  4  5 17 15 19  2 13 11 21 12  6 16 18 10],Val indices_129:[ 7 22  0 20 14]
# Train indices_130:[ 2 14  1 13 17 12 21  4  5  7 16  9 15 19  3  0  8 20],Val indices_130:[11  6 10 22 18]
# Train indices_131:[16 18  9 19 15  1  2  4 14 21  7 11  5 12 20  0  6 22],Val indices_131:[10  8  3 13 17]
# Train indices_132:[12  7  9 19  1 22 16  6  8  2  0 18 11 14 17  3 10 21],Val indices_132:[15  5  4 13 20]
# Train indices_133:[ 6 13  7 18  2 21 19  5  0  3 10  9  4  8 20 22 17 16],Val indices_133:[11  1 14 15 12]
# Train indices_134:[ 3  9  7 20 17 13 22  4 21  0  5 14  6  1 12 11 19 18],Val indices_134:[16 10  2 15  8]
# Train indices_135:[ 6  4 21 18  8  2 22  1 10 19 11 16  7  0 13 14  3  5],Val indices_135:[15  9 17 12 20]
# Train indices_136:[20  0 22  2 12  9  1  4 11 19  8  6 10 17 21 16 13 15],Val indices_136:[14  3  5  7 18]
# Train indices_137:[21  6  1  0 12 22 10  8  5 17 19 20  4 14  7 15  2 13],Val indices_137:[18  9 11 16  3]
# Train indices_138:[ 2  4 16 14 13 22 11 20  8  1  7  5 12  3  0 15  6 18],Val indices_138:[17 19  9 10 21]
# Train indices_139:[11 17  9  4  6  5 13  1 21 20 14  0 16 22  3 10 15 18],Val indices_139:[19  8 12  7  2]
# Train indices_140:[ 4 22 14  1  7  2 17 13  3 16 11 19 15 20 21  9 10 18],Val indices_140:[ 0  8  6  5 12]
# Train indices_141:[ 4 22 11 19 13 20 17  2 21  8  1 14 18 12  3  0  5  7],Val indices_141:[ 9  6 15 16 10]
# Train indices_142:[18  6 11 17 12 16 21  9  1  4  0  7  5 19 15  2  3 22],Val indices_142:[14 20  8 13 10]
# Train indices_143:[12 13  7 10  9  4  2  1  0 22 15  8  6 17 16  3 21 14],Val indices_143:[20 19 11  5 18]
# Train indices_144:[ 1 21 12 16  8 15 14 11 13  0  5 17  6 10  3  7 20 19],Val indices_144:[22  2  4 18  9]
# Train indices_145:[17 20  4 12  0 18 22  9 13  6  2 19  5 14 16 10  8 15],Val indices_145:[11 21  3  7  1]
# Train indices_146:[12  4  0 22  8 10 14  2  6  7 18  9  1 17 21 11  3 15],Val indices_146:[19 20 16 13  5]
# Train indices_147:[16  6  3 10 20 13 22 18 17 15 11  5  4  1 21 14  7  9],Val indices_147:[12 19  0  2  8]
# Train indices_148:[17 20  1 18  6  7 13 19 10  9  0 21  2 22 11  4  3  5],Val indices_148:[12 16 14 15  8]
# Train indices_149:[ 4 19 15 13  6 12 17  5  1  7  9 18 22 20 14 11 10  0],Val indices_149:[16  2  3 21  8]
# Train indices_150:[18 13  8  7 19 16 21  4 11  0 10 14  3  1 12  2 17 15],Val indices_150:[20  5 22  6  9]
# Train indices_151:[10 15  5  0  2  8  7  1  6  4 22 20 11 12  3 21 14 16],Val indices_151:[19 13 18  9 17]
# Train indices_152:[ 0 10 18 15 12 16 13 17  1  7 11  5  3 21  6 19  2 20],Val indices_152:[ 9  4 22  8 14]
# Train indices_153:[19 11 13 20 22  1  7 14 17 21 15  9  8  5 18  0  6  3],Val indices_153:[10  4 16 12  2]
# Train indices_154:[ 1 10 16  8 14 20 19  5 21  3 13  2 12  0  6 17  7 18],Val indices_154:[11 15 22  9  4]
# Train indices_155:[ 3  8 16  1  6 14 21  0 12 10 19  4 17  5 22 11  2 13],Val indices_155:[20 15 18  7  9]
# Train indices_156:[14 20  2 21 18  0  7 10 15 12 13  3  8 22  4  9  5  1],Val indices_156:[ 6 19 17 11 16]
# Train indices_157:[10  8  2 22 14 11  6  4 18  3 16 21  9 13  1  0 15  7],Val indices_157:[ 5 20 17 19 12]
# Train indices_158:[ 7  1  4 18  8  3  0 15 10 22 20 17 13 14  5 11 16 12],Val indices_158:[ 6  9 19 21  2]
# Train indices_159:[14  4  3  2  9  6  7 19  1 22 17 10 18 16 12 13  0 15],Val indices_159:[20  5  8 11 21]
# Train indices_160:[22  6 10 18 11  2 19  1  3 12 20  5 21 16  4 14 17 13],Val indices_160:[ 8  0 15  9  7]
# Train indices_161:[15  9  6 12  1  4  7  3 18 13 14 17 19  2 21 11  0  5],Val indices_161:[20 22 16 10  8]
# Train indices_162:[15  9 13 10 16  3 22  2 17 14 20  5 11  0 21 18  4  8],Val indices_162:[ 1  7 19  6 12]
# Train indices_163:[ 3 22 20  1  0  5  6 15  8 10  2  7  9 14 13 21 16  4],Val indices_163:[18 19 12 17 11]
# Train indices_164:[ 7 20 14  4  3 19  9 10 13 12  8  6 18  5 11 16 22  2],Val indices_164:[17  0 21  1 15]
# Train indices_165:[12  9  8  2 19  5 14  4 18 17 11  1  7  3 20 21 16  6],Val indices_165:[15 22 10  0 13]
# Train indices_166:[ 5  0 17 13  1 18 20 22  3  2 19  9 10 15  6 16  7  4],Val indices_166:[12 14  8 11 21]
# Train indices_167:[ 0  6  7 20 19 18 15  2 10 13 21  4  5  3 22  1 12 16],Val indices_167:[11 14  9  8 17]
# Train indices_168:[21  7  9  6 16  5  0 10 19 15 20 17  4 13  1 14 12 18],Val indices_168:[ 3 11 22  8  2]
# Train indices_169:[22 21  0 11 14  6 20  7  1 15 12 17  5 13  3 16 18  4],Val indices_169:[10 19  9  8  2]
# Train indices_170:[12  4  0 20 14  2  5 13 11  1 18  7  6 16 17 19  9 15],Val indices_170:[10  3 21 22  8]
# Train indices_171:[14  5 21  4 12 17  1 18 13 22 10 11 19  8 15 16 20  3],Val indices_171:[7 6 9 2 0]
# Train indices_172:[13  2  8 17  0  9 19 15  7 16  5 10 12 22 21  1 14 18],Val indices_172:[ 3 20  6  4 11]
# Train indices_173:[ 3  8 19  9  5 12 13  7 14 18  1 22  4  0 15 17  2 10],Val indices_173:[21  6 16 11 20]
# Train indices_174:[ 3 22  6 15 21 12 14  5 20 19  4  2  7  8 18  0 13 10],Val indices_174:[16  9  1 17 11]
# Train indices_175:[ 9 15 20 18  3 22 19  1  0 17  6 21 14  4 10  2 11  7],Val indices_175:[ 5  8 13 16 12]
# Train indices_176:[ 9 21 14  1  7  4  6 12 11  3 18  5 17 20 13 15  2  8],Val indices_176:[ 0 19 10 16 22]
# Train indices_177:[ 1  2 11  6 17 20 13 16 12  7  8 19 18  3  4  9 15 14],Val indices_177:[ 0 21  5 10 22]
# Train indices_178:[11 18 15 16 20  1 22  0  3 17 10 14  9  7 13 12  5 21],Val indices_178:[19  4  8  2  6]
# Train indices_179:[ 2  9  0  8 20 19  5 22 12 16 11 17  3 14 18 10 13 21],Val indices_179:[ 7 15  6  4  1]
# Train indices_180:[ 6  3  1 19 22 20 17 10  7 13 21 14  8  5  0 12 15 16],Val indices_180:[ 2  9 11 18  4]
# Train indices_181:[ 7 11 22 10 15 14  9  6  3 20  2  4 16  0 19 12 21 18],Val indices_181:[ 1  5  8 13 17]
# Train indices_182:[ 1  2 19 12 10 21 13 14 20  7  5  0 22  8  4 18 17  9],Val indices_182:[ 3  6 15 11 16]
# Train indices_183:[18 22 21  5 17  6  9  8 11 20 12  2  7 15  0  4 14  1],Val indices_183:[10 19 13 16  3]
# Train indices_184:[11 20  3  0 21  7 13 18  8 22 17 15  9  4  5 19 10  2],Val indices_184:[ 1  6 12 14 16]
# Train indices_185:[11 17  0 15  6  8 12  3 10  2 13 20  5 16 14  4  9 19],Val indices_185:[ 1  7 22 21 18]
# Train indices_186:[ 5 20 18  1  2  6 16 11 22 14 21 19  9 17 13  4 12  0],Val indices_186:[ 3 10  8 15  7]
# Train indices_187:[ 2 13 18 16 22  9 20 21  1 19  3  8 12  4 11  7 15  6],Val indices_187:[10 17  5  0 14]
# Train indices_188:[13 14 19 18 12  5  7 17  8 21 11 22 16  0  4 15  1  9],Val indices_188:[ 6 20  2  3 10]
# Train indices_189:[12 22 18  5 20 11 13  9  0  4  3  2 14  1 15 16  7  6],Val indices_189:[19 17  8 10 21]
# Train indices_190:[ 1 16  4  0  3 22 21 19  8 18 10 12 17  9 14  2  7 13],Val indices_190:[15 20 11  5  6]
# Train indices_191:[12 15  2 14 11 18 13 21  6 19  0  7  5 20 10 17 22  3],Val indices_191:[ 4  1  9  8 16]
# Train indices_192:[19  3 13 20  6 21  7 22 18 15 12 11 10 16  5  1  2 17],Val indices_192:[ 8 14  0  9  4]
# Train indices_193:[11 12 20 22  0 13 19  7 17  8  4  3 21  9 15  5 10  1],Val indices_193:[16 14  2 18  6]
# Train indices_194:[15 20  2  6  1  7 16  9 21 11  8  0  4  5 22 12 17  3],Val indices_194:[18 13 10 19 14]
# Train indices_195:[ 2 15  1 12 21 22  4 17  0 16  8  9 14  7  5 19 11 20],Val indices_195:[18  3 10 13  6]
# Train indices_196:[ 4  8 12  7 14  3  0 18  1 15 17 11 21 16  5  2  9 22],Val indices_196:[20 19 13  6 10]
# Train indices_197:[13 10 21 17 18 11 16  1  5  0 22 15 20  9 14  8  7 12],Val indices_197:[ 3  4 19  2  6]
# Train indices_198:[ 1  7 16 14  2  8  3  5  0 21 12 15 10 19 13 18 22 11],Val indices_198:[20  9  6  4 17]
# Train indices_199:[15  3 20  4  7  6 16  8 13  2 17  9 11 12 14  0 18  1],Val indices_199:[19 22 21 10  5]
# Train indices_200:[20 12 14  3  2  8 15 19 11 13 10  7 21  0 18 22  1  5],Val indices_200:[16  9  4  6 17]
# Train indices_201:[11 10  9 12 13 21 20 17  2  1 14  8  5  4  0 19 18  3],Val indices_201:[15 16 22  7  6]
# Train indices_202:[13 21 11  7  4 14  1  6 12 10 18 16  8 19  2  0  3 15],Val indices_202:[17  5 22  9 20]
# Train indices_203:[13 16 18  8  9 11 10  2 22 12 20  6  4  0 19 21 14  5],Val indices_203:[ 3 17 15  7  1]
# Train indices_204:[ 5 21  9 20 19 22 11 14 12  1  3 17  4 10  6  7  0 18],Val indices_204:[ 8 15 13 16  2]
# Train indices_205:[12  5  9  7  3 11  4 20 10  8  2 15 22 17  1 19 21 18],Val indices_205:[14  0 16  6 13]
# Train indices_206:[15 19 13 16 22  3 21 20  4  1 11  5  0  7 17  8 12  9],Val indices_206:[ 2 14  6 18 10]
# Train indices_207:[15  5 21 14  7 12 19 20 13  4 17 22 16 11  9  8 18  0],Val indices_207:[ 1  2  6  3 10]
# Train indices_208:[ 8 11 10 17 12 14  6  4 16 13  5 19 18  9  1 20 22 21],Val indices_208:[15  2  0  3  7]
# Train indices_209:[ 6 13 18 10  8 20  9  4 22 15 11 14 16 12  3 21  5  2],Val indices_209:[ 0  1 19  7 17]
# Train indices_210:[14  1 21 10 22 13 11  0  6  7 19  4  9 17 16 20 15 18],Val indices_210:[ 3 12  2  8  5]
# Train indices_211:[ 6  9 13  1 10 17  7 12  0  5  4  8 16  3 18 21 15 19],Val indices_211:[20 11  2 22 14]
# Train indices_212:[ 1 17 19  6  8  9 22  3  4 15  2  7 12 16  5 10 20  0],Val indices_212:[14 18 13 11 21]
# Train indices_213:[11  6 18 22 14 10 19 15 17  5  8  4  1 21 12  7 13  0],Val indices_213:[ 2 20  9 16  3]
# Train indices_214:[20 22  9 19 18  0  2  1 14 11  3  7  5 15  8 21 13 17],Val indices_214:[16  4 12  6 10]
# Train indices_215:[ 5 21 20  7  3 22 18  1 11  2  6 19 12 16 15 10 13  9],Val indices_215:[ 4 17  0  8 14]
# Train indices_216:[13  7 14  4  1 17 11 18 10 15 22  5 20  9  3 19  2 12],Val indices_216:[ 8  6 16 21  0]
# Train indices_217:[ 4 13 12  6  3 22 11 20 21  0  8 18  9  1 15 19  5  2],Val indices_217:[14 10 16 17  7]
# Train indices_218:[22 13  6 10 16  5 15  3 21 20 19  2 18 14  9  1  7 17],Val indices_218:[12  4 11  0  8]
# Train indices_219:[ 0  3  8 18 20 12 14 13 15  5 11 22 17 19 10  7  6 21],Val indices_219:[ 1 16  9  2  4]
# Train indices_220:[10  0 15  7  6 22 13  9 21  4 11  5 12 14 16  2 18 20],Val indices_220:[ 8 17 19  3  1]
# Train indices_221:[14  7 12 16 20  3  4 17 11 13 21 19  8  1  2  6 15  5],Val indices_221:[10 22  9 18  0]
# Train indices_222:[ 3  0 17 18  6 11  9 22  5 16 14 12  1 20  4 19 21 15],Val indices_222:[ 2  7  8 10 13]
# Train indices_223:[ 3 19  6  8  0 11 20  4 17 22 18 21  5 16  1  7 13 15],Val indices_223:[ 9 10 12 14  2]
# Train indices_224:[ 5 17  2 21 13  4 18  0 12 20 11  6 14  8 10 19  9  7],Val indices_224:[16  3  1 22 15]
# Train indices_225:[19  7  9 20  8 17 11  1 13  3  0 10 14  6 22  5 16 18],Val indices_225:[15  2 21 12  4]
# Train indices_226:[17 21 11 18 10  5  0  7 20  1  9 22  4 14  6  2 13  8],Val indices_226:[12 16 19  3 15]
# Train indices_227:[20 10 17  2 22  6 21 16  0  8  1 14  7  9 15  4  3 13],Val indices_227:[18 12 19 11  5]
# Train indices_228:[18 13 15  5 20 16 19  7  9  0 14 12  2 11 21 22  8  4],Val indices_228:[10  3  1 17  6]
# Train indices_229:[ 9  6  8 10  3 16 14 20  2  7 17 18 22 11 15 19  1 12],Val indices_229:[ 4  5  0 21 13]
# Train indices_230:[ 2  8  5 11 17 21 20 15 18  0  3 10  6 22  1 12 16  7],Val indices_230:[ 9 19  4 13 14]
# Train indices_231:[ 7 15 20  3 10  9 19  6  4 12 21 17 18  2 11  8 22 16],Val indices_231:[13 14  5  1  0]
# Train indices_232:[ 7 17  4 19 18 13 22 15 11  9  8 20 16  3  6 21  5 14],Val indices_232:[10  0  1  2 12]
# Train indices_233:[20 12  1  0 19 16 14  9 10  5 11  8  4 17 13  7  6 22],Val indices_233:[15  3  2 21 18]
# Train indices_234:[22 11 14 15 16  9  1 12  5  8  4 13 17 18 20  2  6 21],Val indices_234:[19  3 10  0  7]
# Train indices_235:[11 12  6 15  4  8  1 10 14  3 19 17 16 18  5 21 22  9],Val indices_235:[ 2 13  0  7 20]
# Train indices_236:[19 20  9 11 22  8  6 18  1  3  7 10  5 21 15  0  4 12],Val indices_236:[ 2 13 16 14 17]
# Train indices_237:[21 17 20  0 11 16 15  5 12 13 14  2  3  7 19 22  9  6],Val indices_237:[ 4  1  8 10 18]
# Train indices_238:[10 16 19 21  9 17 22  0 11 20 12  6 13  7  5 18  2  4],Val indices_238:[ 1  3 15 14  8]
# Train indices_239:[18 10  9 17  1  0  7 21 14  4 13 19 22  8  6  3 12 16],Val indices_239:[11 20  5 15  2]
# Train indices_240:[ 1 16 12 11 14  4  7 17  5  6 19  2 22  3 15 10 18  8],Val indices_240:[13 21  9 20  0]
# Train indices_241:[16 10  5  2 11 15  3  1  4 14 21 22  7 20 17 18  8 13],Val indices_241:[12  6  9  0 19]
# Train indices_242:[ 4 21 13  1  8  5 11  7 19 10 17  6 14 20 16 15  2 22],Val indices_242:[ 3  0 18  9 12]
# Train indices_243:[ 7 19  3 17  9 11 21  8 16 14 20 13  6  0 15  2 22  1],Val indices_243:[ 4  5 18 12 10]
# Train indices_244:[22  9  8  0  5 16  4  2 20 19  3 12 18  6 14 21  7  1],Val indices_244:[15 13 17 11 10]
# Train indices_245:[15  5  2  6  9 16 21 13  0 18 20 12 17 14 10  4  8 11],Val indices_245:[19  7 22  3  1]
# Train indices_246:[ 1  2  6 11 21  7  9  4 16 14 17 10  0 12 20  3  5 18],Val indices_246:[15 13 22 19  8]
# Train indices_247:[19 13  9  8 16  0 15 10  5 11  2 21  4  1 18  7  6 12],Val indices_247:[20  3 14 22 17]
# Train indices_248:[13  2 16  1 20 15 19  3 18 14  7 12 11  5 17  0  8 21],Val indices_248:[22  9  6  4 10]
# Train indices_249:[ 8  9 17 22 14 20  5  0 13 11 10 16  2 19  6  1 21  4],Val indices_249:[12  3 18 15  7]
# Train indices_250:[10  1 16 11 12  6 20 18  0  3  4  8 14  7 22  2  5 21],Val indices_250:[ 9 13 15 19 17]
# Train indices_251:[ 3 14  9  1  6 17 18 12 20 15 19 11 10  4  0  7  2 13],Val indices_251:[16 22  5 21  8]
# Train indices_252:[20 18 12 15  7 14  9 19  0 16 21 13  8  6  5 17  2 11],Val indices_252:[10 22  3  1  4]
# Train indices_253:[ 0 19 20 14 15 22  4 13  6  8 17 16 21  1 11  7 12  3],Val indices_253:[ 5 10  2 18  9]
# Train indices_254:[ 1 14 20 11 15 13 19  2  0  7  9  6  4 16 10 12 17  8],Val indices_254:[18 22 21  5  3]
# Train indices_255:[ 4  0  9 13 22 18 14 17  6  5  7 16  3 21 20 15 19  2],Val indices_255:[12 10 11  8  1]
# Train indices_256:[18 19 22 15 14 16 17  1  6  3 20  8  0  9  7  5  2 10],Val indices_256:[ 4 21 11 12 13]
# Train indices_257:[ 5  9  1  8 22 12 21 13  4  0 15 18 19 11 10  2 20 16],Val indices_257:[ 3 17  6 14  7]
# Train indices_258:[17  9  5  8  3 20 16  6 11  2 14  7 19 12  1 15 13 22],Val indices_258:[21 10  0 18  4]
# Train indices_259:[ 8 19 14 13  9 10 16 11  4  3  0  1  5 17 20 22  7 12],Val indices_259:[21 18 15  6  2]
# Train indices_260:[11 22  2  0  3 15  8 20 16 17  4  5 13 14  6  7 10 19],Val indices_260:[21 18  9  1 12]
# Train indices_261:[22 16 13  9 20  8  3 19 15 12  4 10  0  2 21  1 14 17],Val indices_261:[ 7 18  6 11  5]
# Train indices_262:[ 6 20 16  3 14 21 22  4  0 19 15 12  5  1  9 11 18 13],Val indices_262:[17  7  2  8 10]
# Train indices_263:[ 2  5  3 10  4  9  7 22 15 17 12 16  1 20 21  8  6 14],Val indices_263:[19 18 13 11  0]
# Train indices_264:[21 11  8 10 13 16  5 22 19  0  7 20 18  6 17 15  2 14],Val indices_264:[ 9 12  3  1  4]
# Train indices_265:[11 18  1 17 12 10 13 15 14  6  3 16 20 22  5  2 19  8],Val indices_265:[ 4  9  7 21  0]
# Train indices_266:[ 4  1  5 17  0 21  7  9  6 10  2  8 12 15 14 18 13  3],Val indices_266:[22 20 11 19 16]
# Train indices_267:[13 17  3  4 20  5  7  8 10 15 19 14  6  2  1 11 16  9],Val indices_267:[21 12  0 22 18]
# Train indices_268:[ 5  9  1 16  6 17 22  2 10 12 14  8 21  7 20 11 18 19],Val indices_268:[ 4  3 15  0 13]
# Train indices_269:[ 1  0 21 20  7 19  4  2 13  5 10 15 14 22 17 16  9  8],Val indices_269:[11 18  3  6 12]
# Train indices_270:[15 16 17  0 13 11  2 18 10  1 22  4  9 12 21  8  5 20],Val indices_270:[19 14  6  3  7]
# Train indices_271:[ 8 11  4 19 15  0 14 18 17 20 10  9 13  7  5 21 12  6],Val indices_271:[ 1  3 22  2 16]
# Train indices_272:[ 6  4  5  7  1 11  2  0 19 18  3 15  9 22 21 16 14 20],Val indices_272:[12 17 10 13  8]
# Train indices_273:[19 12  0 22  2 11  3 21  7 18 17 20 10  5  4 13  1 15],Val indices_273:[14  8  6  9 16]
# Train indices_274:[12 19  0 20  8 18 15  5 16 21  9  6  2 10 11 17  3  7],Val indices_274:[22 14 13  4  1]
# Train indices_275:[20  1  2 21 19 15 17  3  0  8 12 14 10 18  6  4 11 16],Val indices_275:[ 5 22 13  9  7]
# Train indices_276:[19  5  6 21  1 18  4  7  8 15 14 16 13  9  2 20  3 17],Val indices_276:[ 0 10 12 11 22]
# Train indices_277:[ 8  1  5  0  6 20 10 19 14  9 16 12  4 22 13 15  3  7],Val indices_277:[18 21 11 17  2]
# Train indices_278:[ 4 15  5 10 16  3 21  7  1 13 14 11  9 17 20 19  2 18],Val indices_278:[22 12  8  6  0]
# Train indices_279:[17 11 20  1 22  5  6 10 18  9 14 13 16  8  4  7 19 15],Val indices_279:[21  3  2 12  0]
# Train indices_280:[19 18 20  9 11 10 21  7  5 16  1 15 14  4 22  0 12 13],Val indices_280:[ 6  2 17  3  8]
# Train indices_281:[ 4  1 22 13 14  6  2 20  8  5  3 10  9 18 16  0 21 17],Val indices_281:[19 15 11  7 12]
# Train indices_282:[14 17 11 15 19 12 10 18  3  9  1  4 21  7  0  8 22 20],Val indices_282:[ 5 13  6  2 16]
# Train indices_283:[ 7  5 13  4  6  9 16 19  2 14 10 12  3 21  1  0  8 15],Val indices_283:[11 22 18 17 20]
# Train indices_284:[16 11 18  6 14  0  7 17  2 19 20 12 22  4  5  1  9 10],Val indices_284:[13  8  3 21 15]
# Train indices_285:[22 15  4  0  6 16 18 11  1 13 10 14 20 17  8  3 12  2],Val indices_285:[19 21  5  9  7]
# Train indices_286:[10 14  7 21 12 20 17  5 19 22  2 18 11  1 13  6  8  0],Val indices_286:[15  3  4  9 16]
# Train indices_287:[ 3 14 11 19 16  7  4 18 15 21 13  2 10  1 22  5  6  8],Val indices_287:[12  9  0 17 20]
# Train indices_288:[ 6 17  7 11  1  3  9  0 18  2  4 22 19  8 12 13 15 21],Val indices_288:[16  5 10 14 20]
# Train indices_289:[ 4  8 19  5 13  3 16 11 15  7 21 10 22  2  6 14 20  1],Val indices_289:[18 17 12  9  0]
# Train indices_290:[12 18  7 16  6  4 14 15 22 19 21 13 17 10  0  2 20  5],Val indices_290:[11  8  3  1  9]
# Train indices_291:[ 0  8 19  2 12 15 13 20 16 21 18  4  3 17  6 11  7 14],Val indices_291:[ 5  9  1 22 10]
# Train indices_292:[13 20 16 17 11 19  1  5 10 15  0  4  6 21  8 18 22  3],Val indices_292:[ 7  2 14  9 12]
# Train indices_293:[ 5 10 19  7 17  1 21 15  9 11 13 16 22 12 14  8  2  6],Val indices_293:[20  0  4 18  3]
# Train indices_294:[ 8  6 19  3  9 14 15 17  4 13 11  2 21 22  0 16 10  1],Val indices_294:[18 20  7 12  5]
# Train indices_295:[ 4 11 16  5  0 21 10 17 18  1 14 20 12  2  3  8 15 19],Val indices_295:[ 7 22  6  9 13]
# Train indices_296:[16  9 22 13  0  7 11  3 17 19 14  5 15 10  6 18  1 12],Val indices_296:[21  8  4  2 20]
# Train indices_297:[ 5 22  3 16 14  9  1 11 15  8 20  6 18 17  2  0 13 21],Val indices_297:[10 19 12  7  4]
# Train indices_298:[13 10 22 14  8  5 11 19 16  0 20 18  2 21 15  4  7 12],Val indices_298:[ 1  9  3 17  6]
# Train indices_299:[ 9 18 14  5 17  1  7 15 13 19  2 12  0 20 22 11  6 10],Val indices_299:[21  4  3 16  8]
# Train indices_300:[19  7 11  3  1 15 12  6 20 16  2  4 21 10  8 18 22  0],Val indices_300:[ 9 14 13  5 17]
# Train indices_301:[ 8  9 15 19 12 16  7  4  2 10  5  0 22  1 13 17 14  3],Val indices_301:[ 6 11 20 18 21]
# Train indices_302:[17  8 16 19 14 15 18 11  1  7  5  6  9  2  3  4 20 10],Val indices_302:[13 12 21 22  0]
# Train indices_303:[10 19  5 22  6  7  0  1  2 11 17  9 16 15 14 18  4 21],Val indices_303:[13 12  3 20  8]
# Train indices_304:[ 0  5  8  4 17 16  2  6  7 14  1 19 10 21 11 12  3  9],Val indices_304:[22 18 13 20 15]
# Train indices_305:[ 5 13 21 19 18  7 10  8  2 11 17  0 22 12  9  1 16 15],Val indices_305:[ 4 20  3 14  6]
# Train indices_306:[ 5 20 14 16 18 15 11 10  1  6 22 21 19  2  3  4  0 12],Val indices_306:[13  8  7 17  9]
# Train indices_307:[ 8 20 10 22 11  5  6 14 12 15  1  0  2 13 18  3  7 16],Val indices_307:[17 19  9 21  4]
# Train indices_308:[ 5  0  3 19 10  7 13 14 11  8 17  9  1 21 16 20  4 15],Val indices_308:[18 12  6  2 22]
# Train indices_309:[19  0  1  4  6 16 12  7 14 15 18 21  3 13 10  9 11 20],Val indices_309:[ 2 17 22  8  5]
# Train indices_310:[19  7 16  4 20 21  8 11 13  2 14 15  9  6 22 18  5  3],Val indices_310:[10 12 17  1  0]
# Train indices_311:[ 8 14  0 11 15 20  9 19 22 21  7 17  1 16 18  5 13  3],Val indices_311:[10 12  2  4  6]
# Train indices_312:[20  2 10  4 22 17 19 11  8 21 13  9  5 16 15 14  1 18],Val indices_312:[ 3 12  7  0  6]
# Train indices_313:[17  1 11  7 18 12  0 13 14  2  4 20 15  5 16 21 22 19],Val indices_313:[ 3  6  9  8 10]
# Train indices_314:[10 11 16 19  5  1 15  6 22 12  2 14 17  9 20  4  8 21],Val indices_314:[ 0 18  7 13  3]
# Train indices_315:[14  8  7 21  6  4 15  2  9 11  0  3  5 12 19 16 18 22],Val indices_315:[10 20 17  1 13]
# Train indices_316:[18 12  3 16  9  8 20  6 14 21 11 13  4 19 10  2  1  7],Val indices_316:[17 22  5 15  0]
# Train indices_317:[21  8  3 13  2 22  1  9 18 16  6 14  4 12  0 11 10 15],Val indices_317:[ 5 20 19  7 17]
# Train indices_318:[22 13  0 15  8  7 10  1 14  3  5  9 21 11  6 12 19  4],Val indices_318:[17 16  2 18 20]
# Train indices_319:[18 17 13  5 20  9  1  8  0 10  7  4 15 21 22 14  3  2],Val indices_319:[16  6 19 11 12]
# Train indices_320:[22 19  7 21 14  6  4 11  1 17  3 15 18 13  0  2 10 16],Val indices_320:[ 8 12  5  9 20]
# Train indices_321:[10 21  7 18 16  6 13 12  1  0  3 11 20  2  9  4  8 19],Val indices_321:[ 5 14 17 22 15]
# Train indices_322:[ 5 21 15  1 12  7 19 16  2 18 20 22  0 13 11  4  8  3],Val indices_322:[ 9 10 14 17  6]
# Train indices_323:[22 21  8 12  9  4  0 15  5 16 17  1 20 13  6  3 11 10],Val indices_323:[ 2 14 19  7 18]
# Train indices_324:[18 22 16  8  6 13 12  9  3 19  4  0 20 17 10  2  5  1],Val indices_324:[21 14  7 11 15]
# Train indices_325:[15 11  4 10 20  2  0  6 19 22  3 13 16  5  1 18 21 17],Val indices_325:[12 14  9  8  7]
# Train indices_326:[ 1  2 11 15 14 16 18  4 20  9 10  6 13 17  7  8  0 22],Val indices_326:[19 21 12  5  3]
# Train indices_327:[ 7  2 16 11  9  0 19 20  3 17  5  6 21 10 18  8 14 13],Val indices_327:[ 4 12 22  1 15]
# Train indices_328:[18  4  2 10  3  9 20  8 15 21  7 11 17  6 12 14 22  5],Val indices_328:[16 19  0 13  1]
# Train indices_329:[ 2 17 18  8 20 16 14  9 21 10  0  4 12 11  5 13 22  3],Val indices_329:[ 1 19  6 15  7]
# Train indices_330:[ 9 11  4 10 14 16 22 19 21 17  3 15 12 18  7  2  6  1],Val indices_330:[ 5 20 13  8  0]
# Train indices_331:[19  8  5 18  9 21  4  2 11 14  6 16 20 22  7 12  0 13],Val indices_331:[17  3 15  1 10]
# Train indices_332:[ 8  0 13 16 14 17 15  5 11 19  1  3 20  4 12  6 18  9],Val indices_332:[ 2 10  7 21 22]
# Train indices_333:[14 22  0 16  1  8 15 13  4  7  9 21  2 12 20 10  5 19],Val indices_333:[18 11 17  6  3]
# Train indices_334:[ 0  8 10  4  7 13 18 20 19 21  1 11  6  2 15  5 17 12],Val indices_334:[ 9 22 16 14  3]
# Train indices_335:[20 11  8  7  6 14  4 15 10 21 17 18  3 12  9 16 19  2],Val indices_335:[22  0  1 13  5]
# Train indices_336:[ 2 15 18  7 12  4 17 14  9  5 21  0  3 16  1 19 22 10],Val indices_336:[ 6 11  8 20 13]
# Train indices_337:[ 1 16  3  9 22  4  5 21  8 19  7 18 20 11 12  2 14 13],Val indices_337:[15 17 10  6  0]
# Train indices_338:[12 11  0 17  2  5 10  9  1 20 14  4  7  3 18 16 22 19],Val indices_338:[15  6 13  8 21]
# Train indices_339:[10  3  4 17 16  6 18  8 15 12 21 22  9 14 19  5  2 20],Val indices_339:[ 7  0  1 13 11]
# Train indices_340:[10 14 15 13 22 19  5 16  2 11  0  9  3 17  8  7  4 20],Val indices_340:[12 18  1 21  6]
# Train indices_341:[15  3 18 11 22 21  2 12 13  0  6 19  7  1 14 16  9 20],Val indices_341:[17 10  4  5  8]
# Train indices_342:[20 21  0 10 14 19  4 17 12  7  1  9  8 16 22  2 11  6],Val indices_342:[15 18  5 13  3]
# Train indices_343:[ 3 21  5  2  7 17 20  6 19 11  8 14  9  4 18  0 15 16],Val indices_343:[12 22 10 13  1]
# Train indices_344:[21  6 11  4 22 10 13 14  3  5  8 17  1  2  0 20 12 16],Val indices_344:[ 7 18 15  9 19]
# Train indices_345:[ 7 16 18  4 22 10 12  2 15 21 19  6  8 11 17 13  3 20],Val indices_345:[ 9  5 14  1  0]
# Train indices_346:[ 9  0  1 22 11  2  5 19 17  7 18 21 15 10  8 16 20  6],Val indices_346:[13 14  3 12  4]
# Train indices_347:[21 16  8  3  7  6 17  2 14  9  0 15 12 13 22 20 19  4],Val indices_347:[ 1  5 18 10 11]
# Train indices_348:[10  4 14  3 15 21  7  8  1 13 22 18  0 17 11 19  5  6],Val indices_348:[20 12  9  2 16]
# Train indices_349:[ 1 12 21 17 15  2 20  7  8 10 14  9  5 18 13  3  6 19],Val indices_349:[ 0  4 16 11 22]
# Train indices_350:[ 7 11 19 16 14 10 15 12 21  1  9 17  3 22  5  4 20  0],Val indices_350:[ 2  6  8 13 18]
# Train indices_351:[18  0 17  6  5 12  3  9  1  2 14 21  7 11 22 20 15  8],Val indices_351:[ 4 16 19 10 13]
# Train indices_352:[ 3 21  8  5 17 11  9  7 10  0 19 16  1 14 22 15 13  4],Val indices_352:[12 20  6  2 18]
# Train indices_353:[21  2  4 20 18 19 12 16  1  9 17 13  8  6 14 11  7 22],Val indices_353:[ 0 15  3 10  5]
# Train indices_354:[17 20 18 19 15  1 13 12  4 16 14 21  9 10  3  0  7  6],Val indices_354:[22  2  5  8 11]
# Train indices_355:[14  9 21 20  5  4 19 15  0 17  1  7 13 18  2 11  6  3],Val indices_355:[10  8 12 22 16]
# Train indices_356:[20  7 12  9 16  2  1 14  5 15 11 10 19  6 21  0 18  4],Val indices_356:[22  3 17  8 13]
# Train indices_357:[ 4 12  8 17 21 15 14 18 19  1 22 13  3  7 20  2  0 16],Val indices_357:[11  6 10  5  9]
# Train indices_358:[ 9 14  8 15  4 11  3 22 16  6 21  7  2  0 17  1 10 13],Val indices_358:[ 5 12 20 18 19]
# Train indices_359:[ 1 13  9  7  0 20  5 18  4  2 11 17 19 21 14 16 22  3],Val indices_359:[12 15  8  6 10]
# Train indices_360:[19 14  5 22  8  0 10 18 20  4  1 11 16 12  7 15 13 17],Val indices_360:[ 6  3 21  9  2]
# Train indices_361:[13  8  1 16  9 10  3  5 17 15 18  4 20  2 11 14 12 21],Val indices_361:[19  7  0  6 22]
# Train indices_362:[14 19  6  0  4 17 12  9 11  1 18  2 16 21 15  3 10 22],Val indices_362:[ 5 20 13  7  8]
# Train indices_363:[ 2 19 16 14  3 20 13 15  0  7 10  4 22 18 17  5  1 21],Val indices_363:[ 9  6 12  8 11]
# Train indices_364:[22  3 13  0  5  7 19 15  2 12  1 21  6 16  8 14 20  4],Val indices_364:[10  9 18 17 11]
# Train indices_365:[14 13 12  9  5 22  8  6  0 20 16 11  4  1 18 17 19  3],Val indices_365:[ 2  7 15 21 10]
# Train indices_366:[20  6  8  7  9 21  3 13 17 10  5 18 22 16 19  2  4  0],Val indices_366:[11 15 12 14  1]
# Train indices_367:[ 3 17 15 16 21 14  4  9 13  1 11  6 12 22  5 18  0  2],Val indices_367:[ 8 20  7 10 19]
# Train indices_368:[17  1  4  7 11 18 14 20 22 16 19  0 12  5 13  8  2 10],Val indices_368:[ 6  3 15 21  9]
# Train indices_369:[ 4 15  3 17  9 14 10  0 11 20  1  8 13  7  2 19 12  5],Val indices_369:[18 16  6 22 21]
# Train indices_370:[ 6 15 10 14  9 11 12  7  1 19 20  4 21  0 22 16  3 18],Val indices_370:[ 5  2  8 17 13]
# Train indices_371:[16 22 10  8  1  4 15 18  5 21  6 19  0 13  9  2  7 17],Val indices_371:[20 14  3 11 12]
# Train indices_372:[16  6  9  8 11 20  2  1  3  0 21  7 18 17 19 12  5 22],Val indices_372:[15  4 10 13 14]
# Train indices_373:[11  8  5  7 20  1  0 10 15 17 13  2  3 22 12 16 19  4],Val indices_373:[21  9 18 14  6]
# Train indices_374:[16 17 15 22 19  1 21  4 13  0  8 20 10 12  7  3  5  9],Val indices_374:[ 6 14  2 18 11]
# Train indices_375:[ 4 16 10 13  9  1 22  6 21 14  3  0 19  8 12  2 20  5],Val indices_375:[15 18  7 11 17]
# Train indices_376:[ 0 12 14  5  8 21 22 20 10  2 13  1  9  3 11 19  4 17],Val indices_376:[ 6  7 18 16 15]
# Train indices_377:[ 2 22  6 17 19 11  1  3  0  5 16 20 21  9  4 13  8 15],Val indices_377:[18 12 14 10  7]
# Train indices_378:[ 2  8  7 13 18  9  5 22 12 20 10  0  1 19 11 21  4  3],Val indices_378:[ 6 16 17 14 15]
# Train indices_379:[ 2  8  3  7 14 11 19  0  5 21  4 16  1 13 12 22 20 17],Val indices_379:[ 6 10 18 15  9]
# Train indices_380:[ 6  7 11 18  0 21  1 19  9  5 12 22  3  8 17 20 14  2],Val indices_380:[16  4 13 15 10]
# Train indices_381:[13  7 11 21 16 10  2 15  6  1  5 14 12 22  4 19  8  9],Val indices_381:[ 3  0 17 20 18]
# Train indices_382:[13 15 14  4  1 21  5  9  6  8 20 17  2 11 16 18  3 10],Val indices_382:[ 0 12  7 19 22]
# Train indices_383:[21  6 20 16  9 22  1 19 14 15 17 18  2 13  5  3  8  7],Val indices_383:[ 4 10  0 12 11]
# Train indices_384:[18 12 14 11  1 22 13  5  2  9  8  4 10  6  3 15  0 21],Val indices_384:[20 16 17  7 19]
# Train indices_385:[19 11  6  5 21 20  2 16 22  1  8 17 13  9 15 18 12  3],Val indices_385:[10  0 14  4  7]
# Train indices_386:[16 12 14  7 11  5 17  3 19  8  6  1  4 10 22 21  0 18],Val indices_386:[ 9 20  2 13 15]
# Train indices_387:[ 6  8 12 21 20 10  5  4  7  0 18 16  2 19  1 17 15  9],Val indices_387:[11 22  3 13 14]
# Train indices_388:[13 11 22  3 15  2 12  4  0 10 14 20 19  9  5  8 18 16],Val indices_388:[ 7 21  1 17  6]
# Train indices_389:[ 4 17  0 21 16 19  8 20  3 13 14  7 15 22  5 11  6 18],Val indices_389:[ 9  1 12 10  2]
# Train indices_390:[15 14  1 11 20 16  6  3  2 21 13  4  8 12  9  0 19  7],Val indices_390:[18 22  5 17 10]
# Train indices_391:[ 8 22  5  3 12 18 17  9 20 15  1 10 14  0  2 13  4 19],Val indices_391:[ 6 11 16  7 21]
# Train indices_392:[14  8 15 13  9  6 22  0 16 12 11 21 18  1  5 10 19  7],Val indices_392:[ 2  3 17  4 20]
# Train indices_393:[ 0  3  1 17 19 12  9 18 13 11  5 16  6 15 22  4  2 10],Val indices_393:[14 21  8  7 20]
# Train indices_394:[ 2 14  4  9 11 18  1  7  3 15 10 22  8 20 12 19  0  6],Val indices_394:[21 16  5 13 17]
# Train indices_395:[15 16 14 19  6 11  9  8  0  7  5 22  1  4  2 18 13 20],Val indices_395:[17  3 21 12 10]
# Train indices_396:[17 15  6  9 10  5  0  1 16 19 12  8 14 18 11  3  4 13],Val indices_396:[21  7 22  2 20]
# Train indices_397:[16  6 19  4 12 18 20  2  0  8 10  1 11  7 21 13 17  5],Val indices_397:[15  3 22  9 14]
# Train indices_398:[22 19  4 20  3 11  9  2  7 10  8 15 18  1 13 16 21  5],Val indices_398:[14  6 17  0 12]
# Train indices_399:[ 5  7 13  3  6 16  0 11 10  4 17  8 12  9  2 21 14 20],Val indices_399:[ 1 15 18 19 22]
# Train indices_400:[16  8 13 10 11 18 14  6  2 22 21  7  3  5 20  0  1 19],Val indices_400:[17  9 12  4 15]
# Train indices_401:[20 10 21 14  4  2 22  9  8  1 11 17 15 18 12  3  0  7],Val indices_401:[19  5 16 13  6]
# Train indices_402:[ 1 16 18  3  0 14 12 10 20  7 19  8 21 15  2  9  6 22],Val indices_402:[17 11  4  5 13]
# Train indices_403:[11 19  2  4  5  6 20  0  9  1 21 18 13 10 22  3 17  8],Val indices_403:[12 15 14  7 16]
# Train indices_404:[21  1 19 12  6  8  5  3 22 14  2 15 10 16 20 11 18  7],Val indices_404:[13  9  0 17  4]
# Train indices_405:[ 8 20 16 10  1 17  7  5 21 14  9  0 13 19  3 18  6 22],Val indices_405:[ 4 12 11 15  2]
# Train indices_406:[13 10 14 22  0 21 15  8 20  2  4 11 17 19  5  7  9 18],Val indices_406:[ 3  1 16 12  6]
# Train indices_407:[14  1 13 21 10 20  2  6 18  8  4  9  7 12 16  0  5 17],Val indices_407:[15 11 22  3 19]
# Train indices_408:[17  6 12  0  7  2  3  9 11 22  5 14 10 19  1 13 16 21],Val indices_408:[ 8 20 18  4 15]
# Train indices_409:[ 0  1  5  6 22 18 15 20 16 14 21  8 11 19 12  4  9  7],Val indices_409:[13 10  2 17  3]
# Train indices_410:[14 15 11 13  8  4 10  6  0 20 16 18 19  7  5  1 17  9],Val indices_410:[12 22  2 21  3]
# Train indices_411:[21 13 14 19  5  3 10 17  7  9 11 20  1  2  0  8 22  4],Val indices_411:[18 12  6 15 16]
# Train indices_412:[13 14  5 12 16 18  4  9 11 15 20 17  1  3 21  7  6 19],Val indices_412:[ 8  2  0 22 10]
# Train indices_413:[12 15 19 20 10  2 22  9 17 11  6  8 18  5 13 21 14  1],Val indices_413:[ 4 16  7  3  0]
# Train indices_414:[ 5  2  4  9 21  6 19 11 17 18 12  0 22 20 16  7 14  3],Val indices_414:[15 13  1  8 10]
# Train indices_415:[10  3 14 15  7  6  4 11 19  1 17 13  5 16 18 20 21 12],Val indices_415:[ 9  0 22  8  2]
# Train indices_416:[14  6 12 16 11 17 13 20  0  1 10  8 19 18 21  5 22 15],Val indices_416:[3 9 7 4 2]
# Train indices_417:[13 17  3 18  8  1  6 10 16  9 20 12 22  2  4 15 11  0],Val indices_417:[ 5 14 21  7 19]
# Train indices_418:[11 22 20  7  0  9 13 15 21  2  6 14 19 10 18 17  5 16],Val indices_418:[ 8  1  4 12  3]
# Train indices_419:[21  0  4 16  8 10 17  1 12 15  5  7 22  2 14  9 19 13],Val indices_419:[20 18  6  3 11]
# Train indices_420:[15  1 14  8 16 11 10  6 18  2 12 19 20 17  7  3  5  4],Val indices_420:[22 13  9  0 21]
# Train indices_421:[18  2 17 20  8  1  0 13 14 19 12  5  4 16 15  7 21  6],Val indices_421:[22  3  9 11 10]
# Train indices_422:[18 14  0 16  2  3 21  9  4 10 11  7 15 19 17  6  8  5],Val indices_422:[13 22 20 12  1]
# Train indices_423:[11 22  5 10  1 13 12  8  6 20 14  7 17 15  3 18  0 19],Val indices_423:[ 9 21  4 16  2]
# Train indices_424:[13 16 21  8 17  1 14 15 11 20 18  0 22  3  9  4  7 19],Val indices_424:[12  5  6 10  2]
# Train indices_425:[ 5  7 22 13 21 11  6  3 18  2  4 16  0 14  8 20  9 10],Val indices_425:[19 15  1 17 12]
# Train indices_426:[ 2  6 10 22  0 14  4 11 18  8  5 16 17 19 15 13 21  9],Val indices_426:[20  1  7 12  3]
# Train indices_427:[13 12  2 18  8  9  0  3  5 19  1  6 17  4 10 20 21 15],Val indices_427:[14 11 16 22  7]
# Train indices_428:[17  7 11 13 18  2 16 19  6  4 15  8  3  9 10  0 20 21],Val indices_428:[22 14  1  5 12]
# Train indices_429:[20 19  1 11 21 10 12  2  6 16 13 14  8 15 18  7 17 22],Val indices_429:[4 0 9 5 3]
# Train indices_430:[ 0  3 14  6  7 12 13  8  4 10  9 17  2 22 16 15  1 18],Val indices_430:[20 19 11  5 21]
# Train indices_431:[16  8  3 22 13 12 11 20  7 17 14 15  2  9  1 21  0  4],Val indices_431:[19 10 18  5  6]
# Train indices_432:[17 21  3 14  8 10  2 12 22  6  5 15  0  4 19  9  7 20],Val indices_432:[11 16 13 18  1]
# Train indices_433:[12 14 16  2 11 18 22 19  3 10  4  5  9 20  1  6 13 21],Val indices_433:[15  7 17  0  8]
# Train indices_434:[12 17 21  6  0  4 10  3 22 14 16 20  7  1  9 19 15  5],Val indices_434:[11 18  8 13  2]
# Train indices_435:[22  8  9 11  6 14 15 17 19 16 20  5 10  0  2 12  7  4],Val indices_435:[ 3  1 13 18 21]
# Train indices_436:[21  8  1  4 19  6 13 10  3 20  0 22 14 16 12  5 17 11],Val indices_436:[15  7  9  2 18]
# Train indices_437:[13 14  8 22  7  0 18  4 21 19  9 11 20 15  3 17 12 10],Val indices_437:[16  6  2  1  5]
# Train indices_438:[11 10 18  6 14 16 20  4 17 15 21 22 19 13  7  0  8  1],Val indices_438:[ 3  2 12  9  5]
# Train indices_439:[22  8  7  0  2 20  3 11 15 18 19  5  6  9  4 12  1 17],Val indices_439:[13 21 14 16 10]
# Train indices_440:[ 7  4 22  1  5 11 15 13  0 10 21  8  3  2 20 12 18 17],Val indices_440:[19 14  9 16  6]
# Train indices_441:[ 3  2  6 22 10 13  1  9 19  4  8  0 17 20 14 11 12 15],Val indices_441:[16 21 18  5  7]
# Train indices_442:[12  7 17  5 14 20  4  2 22 21  1 13 10  6 19 16  8 18],Val indices_442:[11  9  3  0 15]
# Train indices_443:[ 3 20 19 16 15  2 21 22 17  5 18  1 11  9 10 14  6  0],Val indices_443:[ 8 12  7 13  4]
# Train indices_444:[ 3 22 11 20  7  8  1 10  9 15 14 16 19 13 17  4 12  2],Val indices_444:[18  5  6 21  0]
# Train indices_445:[21 13 14  6  1 11 19 15  3  8 12  0  2 22  9  5 16  7],Val indices_445:[ 4 10 20 18 17]
# Train indices_446:[14 19  0  2  1 18 20  3  7  8  9 21 10 12 17 22  6 13],Val indices_446:[15 16 11  5  4]
# Train indices_447:[ 3 18 14 10 22 16  6  7  1  5 19 20  9 17 12 21 15  8],Val indices_447:[ 4  0 13 11  2]
# Train indices_448:[10  6 17 13 11  0 20 19 21  5  4  1  3 12  7 22  8 14],Val indices_448:[16 15  9  2 18]
# Train indices_449:[21 15  1 12  8 19  0 10 17 11  3 22  7  5 14 20  4 16],Val indices_449:[18  6  2 13  9]
# Train indices_450:[ 9  0 18 13  3  7  6  1 20 12 21  2 16 19  5 14 11 22],Val indices_450:[15 10  8 17  4]
# Train indices_451:[ 3  4 14  7  0 19 22  6 12  1 21  8 15  9 17  2 11 18],Val indices_451:[16 10 20 13  5]
# Train indices_452:[ 4  5  9 20  8 12  0  2 18  6 11 19 15  7 14 21  1 22],Val indices_452:[16 17 13  3 10]
# Train indices_453:[22 14  2 12  9 20  6  7  8 18 16  5 21  4 17  1 13  3],Val indices_453:[11  0 10 19 15]
# Train indices_454:[11 18 15  7  8  9  3 13 19  4  5  1  6 12  2 10 17  0],Val indices_454:[14 16 20 21 22]
# Train indices_455:[ 9 19 20  0 17 21 15 14  2 12 10  6 16 18  1  4  8  3],Val indices_455:[13 11  5  7 22]
# Train indices_456:[15  3 17  9 10 14 13 11  6 22  8 19  0 18 20  5 21  1],Val indices_456:[16  2  4 12  7]
# Train indices_457:[ 7 19  0  1 20  9  2  5  3 10 14 17 12 16 22 18  4 11],Val indices_457:[ 8  6 21 15 13]
# Train indices_458:[16  9  2  0 15 11  1 14  4 18  3 13 12 22  6 21  8  7],Val indices_458:[20 17 10 19  5]
# Train indices_459:[ 5  8 20  1 21  7  6  2  3 11 12 19 14  0 16  9 15 22],Val indices_459:[ 4 17 10 13 18]
# Train indices_460:[ 1 13  0  2 14 22 12 15 20 19  3  6  9 11  7  8 16  5],Val indices_460:[17 21 18  4 10]
# Train indices_461:[19  2  9 15  7  5 12 10  6 11 13  4 20  1 17 21 22 16],Val indices_461:[14  8  0  3 18]
# Train indices_462:[15  2 11 13  7  6  9 22 10  4  0  5 19 12 16  1 17 18],Val indices_462:[ 3 21 20  8 14]
# Train indices_463:[16 17 15 21 18  7 19 22 20  8  0 14 13  1  3 11  4 12],Val indices_463:[10  2  6  5  9]
# Train indices_464:[11 19 13  9 16  3  5  8 22 17  7 15 12 21  2 10 20  6],Val indices_464:[18  1 14  4  0]
# Train indices_465:[21  9 15  0 17 22 16  5  3 10 19  7  1 12  4  8 14 13],Val indices_465:[ 6 11  2 20 18]
# Train indices_466:[21  0 22 19 17  2 14  8 11  5 10 20 12  6  4  1 18 13],Val indices_466:[16  9  3 15  7]
# Train indices_467:[22 20  0 13  7 21 10  2  3  9 16  4 11  5 17  1 18 12],Val indices_467:[ 8 14 19  6 15]
# Train indices_468:[ 2  6  3 14 20 10 13 22 18 16 15  1 21  7  0 17  4  5],Val indices_468:[19  8 11 12  9]
# Train indices_469:[14 15  9 18  3 22 13 19  5 12  6  7 21 10  8 17  1 16],Val indices_469:[11 20  0  2  4]
# Train indices_470:[17 19 22 16  7 12 10 13 11 14  3  1  9  5  0 20 15 21],Val indices_470:[ 8 18  6  2  4]
# Train indices_471:[14 21  0  1  6 11 20 19 12 22 18 16 17 13 15  7  8  4],Val indices_471:[ 3 10  5  2  9]
# Train indices_472:[ 4 15 19  9 14  6  7 17 11 16 21  5  0 18 22 10 20  3],Val indices_472:[12  1  2 13  8]
# Train indices_473:[10  4 16 19 12 21  1 13  8 20  6 15  2 11  9  7 22 17],Val indices_473:[18 14  0  3  5]
# Train indices_474:[14  3 16 21 19  9  4  8 10 12 22  0 13  5 11  7 20  6],Val indices_474:[ 1 17 15  2 18]
# Train indices_475:[21  7 15 11 14  6  9 16 10 19  0  8 13 12  5  1 20  4],Val indices_475:[22 18  3 17  2]
# Train indices_476:[19 17 21  4 11  9  3  1 20 12 13 16  7  8 14 10 15 22],Val indices_476:[ 5 18  6  2  0]
# Train indices_477:[13  3 15 20 14 17  0 11 12 16  9 10 18  7  6  2  8  1],Val indices_477:[19 22  5 21  4]
# Train indices_478:[ 8 14  2  9 22  5  1 10 13 18  7  0 11 21  3  6  4 12],Val indices_478:[19 20 15 16 17]
# Train indices_479:[15  8  4  2  5  6  0 12 21 17 11  9 16 10 14  7 20 19],Val indices_479:[22  1  3 13 18]
# Train indices_480:[12 13  7 15 17 11 22 18 10 19 21 16  3  6 20 14  2  5],Val indices_480:[0 4 8 9 1]
# Train indices_481:[16  2  4 14 13 12 20 10  5  8 18  0  6 22  3 21 17 11],Val indices_481:[ 1 15 19  7  9]
# Train indices_482:[16  5  4 19  0 12 18  6  1  9  3 20 22  8 14  2 11 13],Val indices_482:[ 7 15 21 10 17]
# Train indices_483:[15 21 13 20 18  3  0  4 12 11 17  6 22  1  9  8 10 19],Val indices_483:[ 7 14  5 16  2]
# Train indices_484:[11 18 13  5 20  1 12 19  9  7  2 15  8 21 14 22  6 16],Val indices_484:[ 4  0 17  3 10]
# Train indices_485:[16 10  7  0  9 13  5 14  2  4 21 22 18  3  1 17 11 19],Val indices_485:[ 6 12  8 15 20]
# Train indices_486:[17 12  9 18  4  1  2 20 11  8 13  5 10  6 14 16  7  3],Val indices_486:[19  0 22 21 15]
# Train indices_487:[ 9 12 18  6 13  0 17 19 11  3  4 10 22 20  2 14  8  1],Val indices_487:[15 16 21  5  7]
# Train indices_488:[11  5  4 18 22 15 12  7 21  6  3  9  0 10  8 19 14 16],Val indices_488:[ 2 20  1 13 17]
# Train indices_489:[21 18  3  9 13  8 19  2 14 15 10 12  5 22  4 20  6 17],Val indices_489:[ 0  1  7 11 16]
# Train indices_490:[12 17  0  6  2 16  8  4 20 15  1 19 18 22 13 10  7 21],Val indices_490:[ 9  5  3 14 11]
# Train indices_491:[ 7  2 22  3 19  0 15 14 10  1 12  9 18  6 17  4 13 20],Val indices_491:[11 16 21  5  8]
# Train indices_492:[ 0 14  5 13  2 11 19 18  8 10  9 20 12  6  4 21  3 16],Val indices_492:[22 17  1  7 15]
# Train indices_493:[ 3  5 14 13 15  0 12 11 20  7  1 16 21 19 17 22  4 10],Val indices_493:[18  2  6  9  8]
# Train indices_494:[16  0  6 22 15 20  5 12  1  9  3 17 19 11  2 18 13  8],Val indices_494:[ 7 14  4 10 21]
# Train indices_495:[ 7  5 17 14  2 11 10 13 16 15  3  4  6 12  8 21  1 18],Val indices_495:[ 0 22 19 20  9]
# Train indices_496:[13 17  2 11  1 22 10 12 19  9  7  5 21 18 16 20  3 15],Val indices_496:[ 4 14  6  8  0]
# Train indices_497:[11 19  2 13 17 14 16 18  5 21  4  3  8 22 15  9 12 20],Val indices_497:[ 0  1  6  7 10]
# Train indices_498:[12  3 14 10  6 20  9  4  1 22 13 15 16  7 17 18  2  5],Val indices_498:[ 8  0 21 11 19]
# Train indices_499:[10  7  6  8  5  2  0  9 22 14 12 16 18 17  3 11  1  4],Val indices_499:[15 20 21 19 13]
# Train sample:9000
# Val sample:2500
# Train distribution:
# count    18.000000
# mean     78.216331
# std       6.755191
# min      64.521000
# 25%      73.907018
# 50%      79.288571
# 75%      82.380598
# max      89.138893
# Name: Score_external, dtype: float64
# Val distribution:
# count     5.000000
# mean     78.278352
# std       6.411052
# min      69.734000
# 25%      75.152905
# 50%      78.884060
# 75%      81.923583
# max      85.697214
# Name: Score_external, dtype: float64

# %%
# 檢查數據類型和內容
print(f"train_valt_indices type: {type(train_val_indices)}")
print('===1/500 sampling===')
print(f"{len(train_val_indices['train_indices'][0])} Train indices for the first sampling(1/500): {train_val_indices['train_indices'][0]}")
print(f"{len(train_val_indices['val_indices'][0])} Val indices for the first sampling(1/500): {train_val_indices['val_indices'][0]}")
# Out:
# train_valt_indices type: <class 'dict'>
# ===1/500 sampling===
# 18 Train indices for the first sampling(1/500): [22, 10, 0, 20, 12, 6, 18, 5, 11, 19, 2, 1, 15, 7, 14, 8, 16, 21]
# 5 Val indices for the first sampling(1/500): [9, 13, 3, 17, 4]

# %%
# 檢查有哪些鍵存在於 train_test_indices 中
print("Available keys:", train_val_indices.keys())
# Out:
# Available keys: dict_keys(['train_indices', 'val_indices'])

# %% [markdown]
# ## Use saved indices to cross validation

# %% [markdown]
# # Project process
# 1. 標準化 X
# 2. 在 train set 上進行 模擬100次 交叉驗證
#     * train loss, val loss
# 3. 無 test set

# %% [markdown]
# ##  prepare variables

# %%
## 重新設定 train_p 的索引
#train_p = train_p.reset_index(drop=True)

# %%
X_all = train_p.drop(columns=['Score_internal', 'Score_external','Rank',
                        'Filename', 'Year', 'Company_Name', 'Life_Ins', 'Property_Ins', 'Company_Name_CN_brief', 'Company_Name_CN', '金控母公司名稱',
                        'Text_cleaned','Text_uncleaned', 'Words', 'Words_top10', 'Words_top100', 'Words_top500' 
                     ])
X_ols = train_p[['vectors_Words','TTR_Bigram500', 'Total_Count_Bigram', '有金控母公司']]
y = train_p['Score_internal']

# %%
#X_ols = train_p[['vectors_Words','TTR_Bigram500', 'Different_Bigrams', '有金控母公司']]

#y = train_p['Score_external']

# %%
X_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   vectors_Wordstop100  23 non-null     float64
#  1   vectors_Wordstop10   23 non-null     float64
#  2   vectors_Words_pca    23 non-null     float64
#  3   tcfd                 23 non-null     int64
#  4   esg                  23 non-null     int64
#  5   Total_Count_Unigram  23 non-null     int64
#  6   Different_Unigrams   23 non-null     int64
#  7   TTR_Unigram500       23 non-null     int64
#  8   TTR_Unigram1000      23 non-null     int64
#  9   TTR_Unigram2000      23 non-null     int64
#  10  TTR_Unigram3000      23 non-null     int64
#  11  TTR_Unigram4000      23 non-null     int64
#  12  TTR_Unigram5000      23 non-null     int64
#  13  Entropy_Unigram500   23 non-null     float64
#  14  Entropy_Unigram1000  23 non-null     float64
#  15  Entropy_Unigram2000  23 non-null     float64
#  16  Entropy_Unigram3000  23 non-null     float64
#  17  Entropy_Unigram4000  23 non-null     float64
#  18  Entropy_Unigram5000  23 non-null     float64
#  19  Simpson_Unigram500   23 non-null     float64
#  20  Simpson_Unigram1000  23 non-null     float64
#  21  Simpson_Unigram2000  23 non-null     float64
#  22  Simpson_Unigram3000  23 non-null     float64
#  23  Simpson_Unigram4000  23 non-null     float64
#  24  Simpson_Unigram5000  23 non-null     float64
#  25  Total_Count_Bigram   23 non-null     int64
#  26  Different_Bigrams    23 non-null     int64
#  27  TTR_Bigram500        23 non-null     int64
#  28  TTR_Bigram1000       23 non-null     int64
#  29  TTR_Bigram2000       23 non-null     int64
#  30  TTR_Bigram3000       23 non-null     int64
#  31  TTR_Bigram4000       23 non-null     int64
#  32  TTR_Bigram5000       23 non-null     int64
#  33  Entropy_Bigram500    23 non-null     float64
#  34  Entropy_Bigram1000   23 non-null     float64
#  35  Entropy_Bigram2000   23 non-null     float64
#  36  Entropy_Bigram3000   23 non-null     float64
#  37  Entropy_Bigram4000   23 non-null     float64
#  38  Entropy_Bigram5000   23 non-null     float64
#  39  Simpson_Bigram500    23 non-null     float64
#  40  Simpson_Bigram1000   23 non-null     float64
#  41  Simpson_Bigram2000   23 non-null     float64
#  42  Simpson_Bigram3000   23 non-null     float64
#  43  Simpson_Bigram4000   23 non-null     float64
#  44  Simpson_Bigram5000   23 non-null     float64
#  45  資本額                  23 non-null     int64
#  46  有金控母公司               23 non-null     int64
#  47  金控母公司是公股             23 non-null     int64
#  48  TCFD_會計師確信           23 non-null     int64
#  49  TCFD_BSI查核           23 non-null     int64
#  50  溫室氣體驗證               23 non-null     int64
#  51  有任第三方驗證              23 non-null     int64
#  52  vectors_Words        23 non-null     float64
#  53  vectors_Wordstop500  23 non-null     float64
# dtypes: float64(29), int64(25)
# memory usage: 9.8 KB

# %% [markdown]
# ##  X Standardization

# %%
# X Standardization
scaler = StandardScaler()
#scaler = MinMaxScaler()
X_all_scaled = scaler.fit_transform(X_all)
X_ols_scaled = scaler.fit_transform(X_ols)

# %% [markdown]
# ## Run simulations and Calculate RMSE stats

# %%
def train_and_evaluate(model, X_train, X_val, y_train, y_val):
    model.fit(X_train, y_train)
    
    # 訓練集預測和 RMSE
    train_predictions = model.predict(X_train)
    train_rmse = np.sqrt(mean_squared_error(y_train, train_predictions))
    
    # 驗證集預測和 RMSE
    val_predictions = model.predict(X_val)
    val_rmse = np.sqrt(mean_squared_error(y_val, val_predictions))

    return train_rmse, val_rmse

# %%
def run_simulation(X_scaled, y, train_val_indices, models, numTrial=100):
    rmse_dict = {model_name: {'train_rmse': [], 'val_rmse': []} for model_name in models}

    # 進行100次訓練和驗證
    for i, (X_train_indices, X_val_indices) in enumerate(zip(train_val_indices['train_indices'], train_val_indices['val_indices'])):
        X_train = X_scaled[X_train_indices]
        X_val = X_scaled[X_val_indices]
        y_train = y.iloc[X_train_indices]
        y_val = y.iloc[X_val_indices]

        for model_name, model in models.items():
            train_rmse, val_rmse = train_and_evaluate(model, X_train, X_val, y_train, y_val)
            rmse_dict[model_name]['train_rmse'].append(train_rmse)
            rmse_dict[model_name]['val_rmse'].append(val_rmse)

    return rmse_dict

# %%
def calculate_rmse_stats(rmse_dict, model_name):
    model_name_map = {
    'Linear Regression': 'LR',
    'Ridge' : 'ridge',
    'Lasso' : 'lasso',
    'Decision Tree': 'DT',
    'Random Forest': 'RF',
    'XGBoost': 'XGB',
    'SVM': 'SVM'
}
    avg_train_rmse = np.mean(rmse_dict['train_rmse'])
    std_train_rmse = np.std(rmse_dict['train_rmse'])
    avg_val_rmse = np.mean(rmse_dict['val_rmse'])
    std_val_rmse = np.std(rmse_dict['val_rmse'])


    model_name_abb = model_name_map[model_name]
    print(f'{model_name_abb}: trainRMSE: {avg_train_rmse:.2f}, trainSD: {std_train_rmse:.2f}, '
          f'valRMSE: {avg_val_rmse:.2f}, valSD: {std_val_rmse:.2f}')
    return [avg_train_rmse, std_train_rmse, avg_val_rmse, std_val_rmse]

# %%
from sklearn.model_selection import GridSearchCV

# 定義 Random Forest 參數網格
param_grid_rf = {
    'n_estimators': [50, 100, 200],#決策樹的個數, 300
    'max_depth': [1, 2, 5],#樹的最大深度, None
    'min_samples_split': [5, 10, 15],#節點中需要的最小樣本數，至少有 2、5 或 10 個樣本時才能繼續分裂
    'min_samples_leaf': [1, 5, 10],   # Minimum samples per leaf
}

# 定義 SVM 參數網格
param_grid_svm = {
    'C': [0.1, 1, 10],#正則化參數[0.1, 1, 10, 100]
    'kernel': ['linear', 'rbf', 'poly'],#核函數線性核（linear）和非線性核（rbf）['linear', 'rbf', 'poly']
    'gamma': ['scale', 'auto']#rbf的作用範圍
}

# 定義 XGB 參數網格
param_grid_xgb = {
    'n_estimators': [50, 100, 200],  # 樹的數量
    #'learning_rate': [0.01, 0.05, 0.1],  # 學習率
    'max_depth': [1, 3, 5, 7],  # 樹的最大深度
    #'subsample': [0.7, 0.8, 1.0],  # 每棵樹用的數據比例
    #'colsample_bytree': [0.7, 0.8, 1.0],  # 每棵樹使用的特徵比例
    'reg_alpha': [0, 0.01, 0.05],  # L1 正則化
    'reg_lambda': [1.5, 2, 2.5]  # L2 正則化
}

# 使用 GridSearchCV 找到最佳的參數
def grid_search_rf(X_train, y_train):
    print("Running Grid Search for Random Forest...")
    rf_model = RandomForestRegressor(random_state=42)
    grid_search_rf = GridSearchCV(estimator=rf_model, param_grid=param_grid_rf, scoring='neg_mean_squared_error', cv=5)
    grid_search_rf.fit(X_train, y_train)
    print(f"Best Parameters for Random Forest: {grid_search_rf.best_params_}")
    best_rf = RandomForestRegressor(random_state=42, **grid_search_rf.best_params_)
    return best_rf # 返回最佳模型

def grid_search_svm(X_train, y_train):
    print("Running Grid Search for SVM...")
    svm_model = SVR()
    grid_search_svm = GridSearchCV(estimator=svm_model, param_grid=param_grid_svm, scoring='neg_mean_squared_error', cv=5)
    grid_search_svm.fit(X_train, y_train)
    print(f"Best Parameters for SVM: {grid_search_svm.best_params_}")
    best_svm = SVR(**grid_search_svm.best_params_)# SVR 沒有 random_state
    return best_svm  # 返回最佳模型

def grid_search_xgb(X_train, y_train):
    print("Running Grid Search for XGBoost...")
    xgb_model = XGBRegressor(random_state=42)
    grid_search_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid_xgb, scoring='neg_mean_squared_error', cv=5)
    grid_search_xgb.fit(X_train, y_train)
    print(f"Best Parameters for XGBoost: {grid_search_xgb.best_params_}")
    best_xgb = XGBRegressor(random_state=42, **grid_search_xgb.best_params_)
    return best_xgb  # 返回最佳模型

# %%
# 加載之前存儲的資料切分索引
train_val_indices = np.load('train_val_indices_regression_property_simulation500.npy', allow_pickle=True).item()
print(len(train_val_indices['train_indices']))
# Out:
# 500

# %%
# 執行 Random Forest 和 SVM 的 Grid Search 並保存最佳參數的模型
best_rf = grid_search_rf(X_all_scaled, y)
best_svm = grid_search_svm(X_all_scaled, y)
best_xgb = grid_search_xgb(X_all_scaled, y)
# 定義模型，使用找到的最佳參數進行訓練
models = {
    #'Linear Regression': LinearRegression(),
    #'Decision Tree': DecisionTreeRegressor(random_state=42),
    #'Ridge' : Ridge(alpha=1.0),
    'Lasso' : Lasso(alpha=0.1),
    'Random Forest': best_rf,
    'XGBoost': best_xgb,
    'SVM': best_svm
}

# 執行模擬
rmse_dict_all = run_simulation(X_all_scaled, y, train_val_indices, models)
rmse_dict_ols = run_simulation(X_ols_scaled, y, train_val_indices, models)
print(rmse_dict_all)
print(rmse_dict_ols)
# Out:
# Running Grid Search for Random Forest...
# Best Parameters for Random Forest: {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Running Grid Search for SVM...
# Best Parameters for SVM: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Running Grid Search for XGBoost...
# Best Parameters for XGBoost: {'max_depth': 1, 'n_estimators': 100, 'reg_alpha': 0.01, 'reg_lambda': 2.5}
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.698e-01, tolerance: 3.621e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.281e+00, tolerance: 3.797e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.185e+00, tolerance: 4.149e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.246e+00, tolerance: 3.157e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.280e-01, tolerance: 2.095e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.547e-01, tolerance: 3.709e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.134e-01, tolerance: 4.206e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.426e+00, tolerance: 4.183e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+00, tolerance: 3.867e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.636e-01, tolerance: 4.016e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.044e-01, tolerance: 3.258e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.510e-01, tolerance: 3.199e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.334e-01, tolerance: 4.266e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.154e+00, tolerance: 4.199e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.627e-01, tolerance: 4.258e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.656e+00, tolerance: 2.682e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.167e-01, tolerance: 4.205e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.129e-01, tolerance: 3.321e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.326e-01, tolerance: 3.413e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.528e-01, tolerance: 4.416e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.392e-01, tolerance: 4.000e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.761e-01, tolerance: 4.105e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.072e+00, tolerance: 3.570e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.540e-01, tolerance: 2.230e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.904e+00, tolerance: 4.099e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.381e-01, tolerance: 4.420e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.592e-01, tolerance: 3.076e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.151e-01, tolerance: 4.256e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.743e+00, tolerance: 4.211e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.935e-01, tolerance: 3.286e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.110e+00, tolerance: 3.873e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.502e-01, tolerance: 2.246e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.919e-01, tolerance: 3.125e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.015e+00, tolerance: 4.165e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.664e-01, tolerance: 3.095e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.258e+00, tolerance: 4.429e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.882e-01, tolerance: 4.140e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.894e-01, tolerance: 3.911e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.840e-01, tolerance: 3.623e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.700e-01, tolerance: 3.683e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.770e-01, tolerance: 2.925e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.659e+00, tolerance: 3.511e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.812e-01, tolerance: 3.132e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.704e-01, tolerance: 3.324e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.749e-01, tolerance: 3.961e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.314e-01, tolerance: 4.293e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.500e-01, tolerance: 2.970e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.908e-01, tolerance: 3.376e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.079e-01, tolerance: 3.773e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.139e+00, tolerance: 4.034e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.127e-01, tolerance: 4.329e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.574e+00, tolerance: 4.137e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.266e-01, tolerance: 3.849e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.476e+00, tolerance: 3.868e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.857e-01, tolerance: 3.503e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.726e-01, tolerance: 2.670e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.963e-01, tolerance: 3.003e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.169e+00, tolerance: 3.972e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.005e-01, tolerance: 3.739e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.802e+00, tolerance: 3.654e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.711e-01, tolerance: 3.475e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.365e-01, tolerance: 3.202e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.702e-01, tolerance: 4.092e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.721e-01, tolerance: 3.449e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.432e-01, tolerance: 3.582e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.219e+00, tolerance: 3.434e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.818e-01, tolerance: 3.112e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.593e+00, tolerance: 4.034e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.205e+00, tolerance: 4.147e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.027e-01, tolerance: 3.950e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.712e-01, tolerance: 3.764e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.896e-01, tolerance: 4.282e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.890e-01, tolerance: 3.464e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.131e-01, tolerance: 2.326e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.107e-01, tolerance: 3.637e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.722e-01, tolerance: 4.075e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.510e-01, tolerance: 3.980e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.097e-01, tolerance: 3.698e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.229e+00, tolerance: 4.046e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.110e+00, tolerance: 3.873e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.669e-01, tolerance: 3.403e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.071e+00, tolerance: 3.720e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.438e-01, tolerance: 4.131e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.475e-01, tolerance: 3.448e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.968e-01, tolerance: 3.080e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.483e-01, tolerance: 2.910e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.429e-01, tolerance: 4.111e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.571e-01, tolerance: 2.596e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+00, tolerance: 3.920e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.614e-01, tolerance: 3.439e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.851e-01, tolerance: 4.043e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.938e-01, tolerance: 2.793e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.561e-01, tolerance: 3.292e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.959e-01, tolerance: 3.793e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.320e+00, tolerance: 3.342e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.082e-01, tolerance: 3.591e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.729e-01, tolerance: 3.750e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.376e-01, tolerance: 3.349e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.112e-01, tolerance: 3.916e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.136e+00, tolerance: 3.469e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.202e-01, tolerance: 2.613e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.190e-01, tolerance: 4.195e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.134e-01, tolerance: 4.116e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.279e-01, tolerance: 3.850e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.985e-01, tolerance: 3.579e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.137e+00, tolerance: 3.738e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.925e-01, tolerance: 3.540e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.368e+00, tolerance: 3.500e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.843e-01, tolerance: 3.045e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.542e-01, tolerance: 3.851e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.025e+00, tolerance: 4.074e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.793e-01, tolerance: 3.921e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.818e-01, tolerance: 2.983e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.895e-01, tolerance: 3.132e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.319e+00, tolerance: 4.342e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.752e+00, tolerance: 3.607e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.279e+00, tolerance: 3.999e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.904e-01, tolerance: 3.926e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.704e+00, tolerance: 2.946e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.046e+00, tolerance: 3.516e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.730e-01, tolerance: 3.397e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.799e-01, tolerance: 3.364e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.305e+00, tolerance: 3.429e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.759e+00, tolerance: 3.729e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.346e-01, tolerance: 3.328e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.308e-01, tolerance: 3.293e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.161e-01, tolerance: 4.176e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.214e-01, tolerance: 3.243e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.060e-01, tolerance: 3.781e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.470e-01, tolerance: 4.335e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.158e-01, tolerance: 3.275e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.077e+00, tolerance: 3.107e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.596e-01, tolerance: 3.302e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.581e-01, tolerance: 3.856e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.825e-01, tolerance: 3.439e-01
#   model = cd_fast.enet_coordinate_descent(
# ...
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.185e-01, tolerance: 4.125e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.805e+00, tolerance: 3.881e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.071e-01, tolerance: 4.186e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.219e-01, tolerance: 3.207e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.169e-01, tolerance: 3.775e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+00, tolerance: 4.197e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.924e-01, tolerance: 4.464e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.469e-01, tolerance: 3.979e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.755e-01, tolerance: 4.232e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.256e-01, tolerance: 4.218e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.688e-01, tolerance: 3.056e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.068e-01, tolerance: 3.835e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.813e-01, tolerance: 2.671e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.028e-01, tolerance: 2.207e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.684e-01, tolerance: 2.890e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.226e-01, tolerance: 4.154e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.548e-01, tolerance: 4.110e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.054e+00, tolerance: 2.893e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.489e-01, tolerance: 3.391e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.919e-01, tolerance: 3.125e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.657e-01, tolerance: 3.231e-01
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\USER\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.751e-01, tolerance: 3.046e-01
#   model = cd_fast.enet_coordinate_descent(
# {'Lasso': {'train_rmse': [4.68377809971554, 4.716158336112209, 5.036283580799141, 4.546580467590622, 4.947482300377023, 5.2235709829203305, 5.486262432302163, 4.9274275330744866, 5.325153289854466, 4.771221453606053, 2.314117037070515, 4.619522777062213, 3.2818397195744553, 4.987360922724972, 5.110837788462349, 4.8309696381776, 3.1791180038928117, 4.596606290514536, 5.607544847291958, 5.0127032698070275, 2.8519965679322894, 5.247740786063648, 5.185549205119762, 5.095250415903141, 5.414271375557995, 3.0399584694027086, 4.99945995686124, 4.844953568687219, 2.5972491803115934, 4.889043633769173, 4.7253555513685335, 5.342584797033365, 4.601540607890532, 5.350994491823915, 4.765655656909975, 4.715284194792204, 5.469440158879379, 3.053738895739815, 4.723622574909664, 5.033528261613092, 2.4420829902567482, 2.129028234467736, 5.500620667806624, 3.554247359751034, 5.557523271422052, 4.309214467448669, 3.4061603897415935, 5.464647491668404, 5.063003316461406, 1.7133744760560103, 2.9019266939988344, 5.0321637154723025, 4.59692971805927, 5.547852707805396, 3.093219027072954, 2.863493371505212, 4.818679036403462, 3.335407668576747, 4.064596141931463, 4.608020336671297, 4.840220410441275, 4.557533544294829, 1.5954624116119869, 4.471123515276601, 4.108734794847922, 4.52745881386221, 5.019049441876594, 4.613830207252213, 3.699628510171358, 5.217862802633012, 4.67156304028087, 4.837990950361718, 3.285636964445236, 3.5381103268130687, 3.1593424898522846, 5.057682307225446, 4.047125645039398, 1.9254973980276828, 3.321442962505362, 2.94675747346304, 5.035282417620135, 4.919243969819775, 2.9055290191205723, 4.619432483440547, 5.276153151258928, 4.728620610606133, 5.092663919948082, 5.652432789143538, 3.2059178005906808, 4.8915760698085755, 4.376145796248585, 4.98355173800636, 2.3049633122436424, 4.7567158148353785, 5.399714475620629, 3.259904925830214, 4.5610289654093235, 5.472102862732739, 3.256564866265569, 3.829134633617684, 5.426093202676658, 5.3272472534770205, 3.7912563807174764, 5.144049011221082, 3.452247729444341, 4.310090172120803, 5.739951953835449, 4.49774352162342, 4.705312239134281, 4.626679807454056, 2.5306751222349932, 5.008934755650866, 4.407505202117695, 2.4771615771706212, 2.442927207784482, 4.781991912355854, 5.100216922185054, 5.312734413499714, 4.422874283574166, 3.9052760985774877, 3.2485934773978444, 2.0759547617581977, 2.255390594713923, 5.404994281029854, 2.474831700367499, 5.2944355000039955, 3.9847946956671776, 2.9760207279502797, 4.541108575915477, 3.9067390513553844, 4.967751227199054, 2.34578725430792, 5.411625939732769, 5.5600362617052115, 2.643676287508299, 4.785176906549067, 3.8995973213417927, 4.702299011172106, 4.91215447173018, 2.889190449733547, 3.043233463905076, 5.25699185677553, 3.4005505301086756, 5.022482845798067, 4.395270740811061, 4.779462014478181, 5.527703047682573, 2.863493371505204, 2.9597005556513034, 3.0281464644875595, 5.318576886545838, 4.837296253622233, 3.284119257496996, 4.8829353430850855, 4.956508150012598, 3.7089274874859335, 4.696342355817078, 4.86724979719154, 5.369571843105855, 3.520897901117036, 2.711992111697688, 3.5300823293679784, 3.952709050835673, 4.938768159009415, 4.554837954806734, 4.738633025169661, 3.1765946757603922, 2.376775881953779, 2.7919342531587494, 3.3194764728187462, 3.594175055897761, 4.232862806357043, 5.403545595422248, 5.522835499752771, 4.63487361517838, 3.326343613652562, 4.666874253321482, 4.8684651582584495, 2.9697870367034374, 4.167943140785654, 4.7822677132247655, 2.2810643129927493, 5.52737148290142, 5.387325851415079, 5.2600707147362264, 3.874375910681139, 3.116485572236362, 4.657748761224337, 5.337183974041456, 2.49489870306056, 5.607295876425897, 3.2732917971146316, 3.3574463948821758, 4.173547286610546, 4.99160798328547, 4.972498336018608, 5.559197144809145, 4.71182057151085, 4.550998531084905, 5.398699056625317, 4.120877286700286, 4.665203932983958, 4.728086717897295, 4.120255105437733, 2.720457863347442, 5.0490977788312525, 4.931849638860624, 5.4675 ...
# {'Lasso': {'train_rmse': [8.03088123981752, 8.40137680218433, 8.473677985776112, 8.506184049526585, 8.03858531180434, 8.617519925017637, 7.460944463175833, 8.659695832230291, 7.7207444174681585, 7.821762406720263, 7.9871796813540055, 8.381312206432392, 7.777204404623487, 8.04998269300579, 7.221616491125059, 7.767497891173491, 7.5640491589910654, 8.334325276463971, 7.879013422002071, 7.485193215127971, 6.643605202800027, 8.283730152958391, 8.311979982019672, 8.402713675455816, 8.645319527620682, 8.604567617668645, 6.7466792032417215, 8.951259467215348, 7.747316068095, 8.165873724144017, 8.408528277634659, 7.944242683033358, 7.005336393381144, 7.62778419278744, 8.626925818262414, 8.274669578064827, 8.41862764493671, 8.499537953889837, 7.354008233062048, 8.042331342925262, 7.055798917841228, 7.672775016504555, 6.744140308621057, 7.823651886780248, 8.503113866383318, 7.827089607721554, 8.016651444406108, 8.959135340386593, 7.806819413820962, 6.212868942628213, 7.720525053528807, 8.809117544399369, 8.674953216379793, 7.284027120769799, 7.206097531887664, 7.839334519774845, 8.86189881454268, 6.453782487441206, 7.011581892156473, 7.894563372078168, 8.279216004863281, 8.349633068071213, 7.720581868740677, 8.744549112705414, 7.199911320184976, 8.070420497064356, 8.440926669035079, 8.562734611129923, 8.093494504391114, 8.652690896115132, 7.314356320710284, 8.124651441869167, 8.442110231646677, 8.480390243277885, 7.77332837562282, 8.117574503093794, 8.686938142874592, 8.256166157184994, 7.714478530098179, 7.644031973291984, 8.62250734818606, 8.664420427513763, 8.095628456015174, 7.886251535487377, 8.314468704623378, 8.091942144781024, 7.917654221034496, 8.582093507040963, 8.284220785161777, 8.475254212692874, 8.577655492724578, 8.510417064146088, 6.840397872924219, 8.504786163730127, 7.437065114210984, 7.697688641168673, 8.802050373917035, 8.365335891013078, 6.840564524648052, 7.873291833508196, 7.179739116046708, 7.29470035264972, 8.517625611073962, 8.942039885667596, 7.929398917931734, 7.693737465869039, 7.225913976093235, 6.99561713779686, 8.130619693987166, 8.03028221363941, 7.5908568848845785, 8.689923270036727, 7.206653860061092, 8.24980781698332, 7.083811634897217, 8.089987871557296, 8.479994421564909, 8.046165338973182, 8.137790839158793, 8.020731520749742, 7.8966410266491875, 8.045406358311931, 7.840881784082099, 7.928095365968404, 7.405879684960003, 7.6127467455834905, 7.987518729746555, 8.514199291840018, 9.013274491453023, 7.400899537848677, 9.207920022575221, 8.092847128046118, 7.9328356855912165, 7.1276364796595475, 7.326401588295071, 7.318946640966684, 7.784503930583161, 8.379874629392733, 7.905354544381322, 7.55212049826216, 8.494085237578476, 7.600234989156752, 7.305115771260322, 8.825322486984938, 8.339542854655502, 8.099622254007617, 8.460444092528858, 7.8393345197748445, 6.621543170621084, 7.790743293417822, 8.174085581636005, 7.980903900821946, 7.39002094779302, 8.438782163491464, 7.915655813213572, 7.291119215666674, 7.948050111267579, 8.58044468185764, 8.309503550036153, 8.237244760753915, 6.748724683013636, 7.854639125598166, 7.35244241140873, 8.570147140040662, 7.430769978471016, 8.253842744293713, 7.82880426246158, 7.126514899851827, 8.22120697311576, 7.6913573398972765, 8.35181687314365, 7.976080028941957, 8.482112303392261, 8.70662580411461, 7.198873337445987, 8.289475642192699, 8.373465099423209, 9.0557590892878, 7.913024243835461, 7.280584813538513, 8.384185317211335, 7.413381887982512, 7.827199154078221, 8.345867116479967, 7.928089389540429, 7.884834914488587, 7.354314414154395, 8.155612630374623, 8.49945457831856, 7.872615136149471, 8.353633998637806, 6.583781023127431, 7.307287751405456, 8.089432232836089, 7.780568426868249, 8.900524614496327, 8.687615082948767, 8.116861743806044, 7.919750148085875, 8.89100684791132, 7.5844699537109035, 7.972177278986439, 7.901436551677654, 7.080002925319861, 7.268779800033122, 8.13459896851135, 8.05021821002572, 8.483612506996446, 7.62176900457461, 6.972690618531179, 8.2 ...

# %%
print('===all===')
rmse_summary_all = {model_name: calculate_rmse_stats(rmse_dict_all[model_name], model_name) for model_name in models}
print('===ols===')
rmse_summary_ols = {model_name: calculate_rmse_stats(rmse_dict_ols[model_name], model_name) for model_name in models}
# Out:
# ===all===
# lasso: trainRMSE: 4.33, trainSD: 0.97, valRMSE: 12.97, valSD: 3.42
# RF: trainRMSE: 5.70, trainSD: 0.44, valRMSE: 11.95, valSD: 2.43
# XGB: trainRMSE: 1.07, trainSD: 0.24, valRMSE: 12.92, valSD: 2.56
# SVM: trainRMSE: 6.05, trainSD: 0.89, valRMSE: 11.81, valSD: 3.07
# ===ols===
# lasso: trainRMSE: 7.99, trainSD: 0.55, valRMSE: 10.54, valSD: 2.42
# RF: trainRMSE: 6.63, trainSD: 0.44, valRMSE: 11.90, valSD: 2.79
# XGB: trainRMSE: 2.98, trainSD: 0.46, valRMSE: 11.26, valSD: 2.45
# SVM: trainRMSE: 10.61, trainSD: 0.80, valRMSE: 11.92, valSD: 3.47

# %% [markdown]
# ## Visualization
# ### Compare models

# %%
# 構造數據框以繪製箱型圖
def prepare_boxplot_data(rmse_dict_all, rmse_dict_ols):
    model_names = []
    rmse_values = []
    dataset_types = []  # 'train' or 'val'
    feature_sets = []  # 'All Features' or 'OLS'

    for model_name in rmse_dict_all:
        # All Features Train RMSE
        model_names.extend([model_name] * len(rmse_dict_all[model_name]['train_rmse']))
        rmse_values.extend(rmse_dict_all[model_name]['train_rmse'])
        dataset_types.extend(['train'] * len(rmse_dict_all[model_name]['train_rmse']))
        feature_sets.extend(['All Features'] * len(rmse_dict_all[model_name]['train_rmse']))

        # All Features Validation RMSE
        model_names.extend([model_name] * len(rmse_dict_all[model_name]['val_rmse']))
        rmse_values.extend(rmse_dict_all[model_name]['val_rmse'])
        dataset_types.extend(['val'] * len(rmse_dict_all[model_name]['val_rmse']))
        feature_sets.extend(['All Features'] * len(rmse_dict_all[model_name]['val_rmse']))

        # OLS Train RMSE
        model_names.extend([model_name] * len(rmse_dict_ols[model_name]['train_rmse']))
        rmse_values.extend(rmse_dict_ols[model_name]['train_rmse'])
        dataset_types.extend(['train'] * len(rmse_dict_ols[model_name]['train_rmse']))
        feature_sets.extend(['Proposed'] * len(rmse_dict_ols[model_name]['train_rmse']))

        # OLS Validation RMSE
        model_names.extend([model_name] * len(rmse_dict_ols[model_name]['val_rmse']))
        rmse_values.extend(rmse_dict_ols[model_name]['val_rmse'])
        dataset_types.extend(['val'] * len(rmse_dict_ols[model_name]['val_rmse']))
        feature_sets.extend(['Proposed'] * len(rmse_dict_ols[model_name]['val_rmse']))

    # 將數據轉換為 DataFrame
    boxplot_data = pd.DataFrame({
        'Model': model_names,
        'RMSE': rmse_values,
        'Dataset': dataset_types,
        'Feature Set': feature_sets
    })
    
    return boxplot_data

# %%
prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
# Out:
#       Model       RMSE Dataset   Feature Set
# 0     Lasso   4.683778   train  All Features
# 1     Lasso   4.716158   train  All Features
# 2     Lasso   5.036284   train  All Features
# 3     Lasso   4.546580   train  All Features
# 4     Lasso   4.947482   train  All Features
# ...     ...        ...     ...           ...
# 7995    SVM   9.831534     val      Proposed
# 7996    SVM  12.892351     val      Proposed
# 7997    SVM  12.911860     val      Proposed
# 7998    SVM  17.176976     val      Proposed
# 7999    SVM  14.208263     val      Proposed
#
# [8000 rows x 4 columns]

# %%
def plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols):
    # Prepare the data for the boxplot
    data = prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
    data['Model'] = data['Model'].replace({'Lasso': 'Lasso Regression'})
    
    fig, axs = plt.subplots(1,2,figsize=(16, 6))
    # Set general style
    sns.set(style="whitegrid", font_scale=1.2)  # Scale font size
    
    # Draw the first boxplot with 'Dataset' (train/val) as the hue
    sns.boxplot(ax=axs[0], x='Model', y='RMSE', hue='Dataset', data=data, palette='Set2', linewidth=2)
    #axs[0].set_title('RMSE by Dataset', fontsize=16)
    axs[0].set_xlabel('Models', fontsize=12)
    axs[0].set_ylabel('RMSE', fontsize=12)
    axs[0].legend(fontsize=12, loc='upper right')

    # Draw the second boxplot with 'Feature Set' (All Features/Proposed) as the hue
    sns.boxplot(ax=axs[1], x='Model', y='RMSE', hue='Feature Set', data=data, palette='Set2', linewidth=2)
    #axs[1].set_title('RMSE by Feature Set', fontsize=16)
    axs[1].set_xlabel('Models', fontsize=12)
    axs[1].set_ylabel('RMSE', fontsize=12)
    axs[1].legend(fontsize=12, loc='upper right')

    # Add grid and adjust tick params for all subplots
    for ax in axs.flat:
        ax.grid(True, linestyle='--', linewidth=0.5)
        ax.tick_params(axis='both', which='major', labelsize=12)

    # Adjust subplot spacing
    plt.subplots_adjust(wspace=0.1, hspace=0.5, left=0.1, right=0.9)  # Adjust subplot layout

    # Save figure
    #plt.savefig('all54_vs_proposed4_property_external_model.png', dpi=1000, bbox_inches='tight')
    plt.savefig('all54_vs_proposed4_property_internal_model.png', dpi=1000, bbox_inches='tight')

    # Adjust layout and display the plot
    plt.tight_layout()
    plt.show()


# 調用函數來繪製 boxplot
plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols)

# %% [markdown]
# #### Combined

# %%
def plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols):
    # Prepare the data for the boxplot
    data = prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
    data['Model'] = data['Model'].replace({'Lasso': 'Linear Regression'})
    plt.figure(figsize=(14, 8))
    
    # Draw a boxplot with 'Dataset' (train/val) as the hue
    sns.boxplot(x='Model', y='RMSE', hue='Dataset', data=data, palette='Set2', linewidth=2)
    
    #plt.title('RMSE Comparison Across Models', fontsize=16)
    plt.xlabel('Models', fontsize=15)
    plt.ylabel('RMSE', fontsize=15)
    plt.xticks(fontsize = 15)#rotation=45, 
    plt.yticks(fontsize = 15)
    plt.legend(fontsize=15, loc='upper right')
    
    plt.show()
# 調用函數來繪製 boxplot
plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols)

# %%
def plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols):
    # Prepare the data for the boxplot
    data = prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
    data['Model'] = data['Model'].replace({'Lasso': 'Linear Regression'})
    plt.figure(figsize=(14, 8))
    
    # Draw a boxplot with 'Dataset' (train/val) as the hue
    sns.boxplot(x='Model', y='RMSE', hue='Feature Set', data=data, palette='Set2', linewidth=2)
    
    #plt.title('RMSE Comparison Across Feature Sets', fontsize=16)
    plt.xlabel('Models', fontsize=15)
    plt.ylabel('RMSE', fontsize=15)
    plt.xticks(fontsize = 15)#rotation=45, 
    plt.yticks(fontsize = 15)
    plt.legend( fontsize=15, loc='upper right')
    #title='Dataset', title_fontsize=15,
    plt.show()

# 調用函數來繪製 boxplot
plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols)

# %% [markdown]
# ## Compare features and models

# %%
def plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols):
    # Prepare the data for the boxplot
    data = prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
    data['Model'] = data['Model'].replace({'Lasso': 'Linear Regression'})
    
    # Combine Dataset and Feature Set into a single column to create distinct categories for boxplots
    data['Feature_Dataset'] = data['Feature Set'] + ' ' + data['Dataset']
    
    plt.figure(figsize=(8, 6))#14, 8
    sns.set(style="whitegrid", font_scale=1.2)  # Scale font size
    
    # Draw a boxplot with combined 'Feature Set' and 'Dataset' for x-axis grouping
    sns.boxplot(x='Model', y='RMSE', hue='Feature_Dataset', data=data, palette='Set2', linewidth=2)
    # Add gridlines
    plt.grid(visible=True, which='major', linestyle='--', linewidth=0.5, axis='both')
    
    #plt.title('RMSE Comparison Across Models and Feature Sets', fontsize=16)
    plt.xlabel('Models', fontsize=12)
    plt.ylabel('RMSE', fontsize=12)
    plt.xticks(fontsize = 12)
    plt.yticks(fontsize = 12)
    plt.legend(fontsize=12, loc='upper right')

    # Save figure
    #plt.savefig('all54_vs_proposed4_property_external_model&feature.png', dpi=1000, bbox_inches='tight')
    plt.savefig('all54_vs_proposed4_property_internal_model&feature.png', dpi=1000, bbox_inches='tight')
   
    # Adjust layout and display the plot
    plt.tight_layout()    
    plt.show()

# Call the function to plot the boxplot comparison
plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols)

# %% [markdown]
# ## Compare features

# %%
def plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols):
    # Prepare the data for the boxplot
    data = prepare_boxplot_data(rmse_dict_all, rmse_dict_ols)
    data['Model'] = data['Model'].replace({'Lasso': 'Linear Regression'})
    
    # Combine Dataset and Feature Set into a single column to create distinct categories for boxplots
    data['Feature_Dataset'] = data['Feature Set'] + ' ' + data['Dataset']
    
    plt.figure(figsize=(8, 6))#14, 8
    sns.set(style="whitegrid", font_scale=1.2)  # Scale font size
       
    # Draw a boxplot with combined 'Feature Set' and 'Dataset' for x-axis grouping
    sns.boxplot(x='Feature Set', y='RMSE', hue='Model', data=data, palette='Set2', linewidth=2)
    # Add gridlines
    plt.grid(visible=True, which='major', linestyle='--', linewidth=0.5, axis='both')
     
    #plt.title('RMSE Comparison Across Models and Feature Sets', fontsize=16)
    plt.xlabel('Models', fontsize=12)
    plt.ylabel('RMSE', fontsize=12)
    plt.xticks(fontsize = 12) 
    plt.yticks(fontsize = 12)
    plt.legend(fontsize=12, loc='upper right')

    # Save figure
    #plt.savefig('all54_vs_proposed4_property_external_feature.png', dpi=1000, bbox_inches='tight')
    plt.savefig('all54_vs_proposed4_property_internal_feature.png', dpi=1000, bbox_inches='tight')
   
    # Adjust layout and display the plot
    plt.tight_layout()     
    plt.show()

# Call the function to plot the boxplot comparison
plot_boxplot_comparison(rmse_dict_all, rmse_dict_ols)
